# %%
import pandas as pd
import numpy as np
import pickle
import sys
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem.porter import *
import string
import re
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer as VS
from textstat.textstat import *
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt
import seaborn
from sklearn.model_selection import train_test_split
# %matplotlib inline
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv("data/train/training_data.csv")

# %%
tweets=df.tweet

# %% [markdown]
# ## Davidson Feature Generation

# %%
stopwords=stopwords = nltk.corpus.stopwords.words("english")

other_exclusions = ["#ff", "ff", "rt"]
stopwords.extend(other_exclusions)

stemmer = PorterStemmer()


def preprocess(text_string):
    """
    Accepts a text string and replaces:
    1) urls with URLHERE
    2) lots of whitespace with one instance
    3) mentions with MENTIONHERE

    This allows us to get standardized counts of urls and mentions
    Without caring about specific people mentioned
    """
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, '', parsed_text)
    parsed_text = re.sub(mention_regex, '', parsed_text)
    return parsed_text

def tokenize(tweet):
    """Removes punctuation & excess whitespace, sets to lowercase,
    and stems tweets. Returns a list of stemmed tokens."""
    tweet = " ".join(re.split("[^a-zA-Z]*", tweet.lower())).strip()
    tokens = tweet.split() #[stemmer.stem(t) for t in tweet.split()]
    return tokens

def basic_tokenize(tweet):
    """Same as tokenize but without the stemming"""
    tweet = " ".join(re.split("[^a-zA-Z.,!?]*", tweet.lower())).strip()
    return tweet.split()

vectorizer = TfidfVectorizer(
    tokenizer=tokenize,
    preprocessor=preprocess,
    ngram_range=(1, 3),
    stop_words=stopwords,
    use_idf=True,
    smooth_idf=False,
    norm=None,
    decode_error='replace',
    max_features=10000,
    min_df=5,
    max_df=0.75
    )

# %%
#Construct tfidf matrix and get relevant scores
tfidf = vectorizer.fit_transform(tweets).toarray()
vocab = {v:i for i, v in enumerate(vectorizer.get_feature_names())}
idf_vals = vectorizer.idf_
idf_dict = {i:idf_vals[i] for i in vocab.values()} #keys are indices; values are IDF scores
# Out:
# /anaconda2/envs/nlu/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['b', 'c', 'e', 'f', 'g', 'h', 'j', 'l', 'n', 'p', 'r', 'u', 'v', 'w'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
#Get POS tags for tweets and save as a string
tweet_tags = []
for t in tweets:
    tokens = basic_tokenize(preprocess(t))
    tags = nltk.pos_tag(tokens)
    tag_list = [x[1] for x in tags]
    tag_str = " ".join(tag_list)
    tweet_tags.append(tag_str)

# %%
#We can use the TFIDF vectorizer to get a token matrix for the POS tags
pos_vectorizer = TfidfVectorizer(
    tokenizer=None,
    lowercase=False,
    preprocessor=None,
    ngram_range=(1, 3),
    stop_words=None,
    use_idf=False,
    smooth_idf=False,
    norm=None,
    decode_error='replace',
    max_features=5000,
    min_df=5,
    max_df=0.75,
    )

# %%
#Construct POS TF matrix and get vocab dict
pos = pos_vectorizer.fit_transform(pd.Series(tweet_tags)).toarray()
pos_vocab = {v:i for i, v in enumerate(pos_vectorizer.get_feature_names())}

# %%
def count_twitter_objs(text_string):
    """
    Accepts a text string and replaces:
    1) urls with URLHERE
    2) lots of whitespace with one instance
    3) mentions with MENTIONHERE
    4) hashtags with HASHTAGHERE

    This allows us to get standardized counts of urls and mentions
    Without caring about specific people mentioned.
    
    Returns counts of urls, mentions, and hashtags.
    """
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    hashtag_regex = '#[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, 'URLHERE', parsed_text)
    parsed_text = re.sub(mention_regex, 'MENTIONHERE', parsed_text)
    parsed_text = re.sub(hashtag_regex, 'HASHTAGHERE', parsed_text)
    return(parsed_text.count('URLHERE'),parsed_text.count('MENTIONHERE'),parsed_text.count('HASHTAGHERE'))

# %% [markdown]
# ## Preprocess for slang

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

# %%
def load_slang_dict():
    slang_dict = {}
    with open("slang_to_words.txt", 'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.strip().split('\t')
            #print(tokens[1])
            slang_dict[tokens[1]] = tokens[0]
    return slang_dict
slang_dict_one = load_slang_dict()
#slang_dict

# %%
def load_slang_two_dict():
    slang_dict_two = {}
    with open("noslangdotcom.txt", 'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.strip().split(':')
            #print(tokens[1])
            slang_dict_two[tokens[0]] = tokens[1]
    return slang_dict_two
slang_dict_two = load_slang_two_dict()
#slang_dict_two

# %%
def load_slang_three_dict():
    slang_dict_three = {}
    with open("internet_slangsDotNet.txt", 'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.strip().split('==')
            slang_dict_three[tokens[0]] = tokens[1]
            #print("first ", tokens[0], "second ", tokens[1])
    return slang_dict_three
slang_dict_three = load_slang_three_dict()

# %%
def load_slang_four():
    slang_dict_four = {}
    with open("common_twitter_abbreviations.txt", 'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.strip().split('=')
            slang_dict_four[tokens[0]] = tokens[1]
    return slang_dict_four
slang_dict_four = load_slang_four()

# %%
def merge_dicts(*dict_args):
    """
    Given any number of dicts, shallow copy and merge into a new dict,
    precedence goes to key value pairs in latter dicts.
    """
    result = {}
    for dictionary in dict_args:
        result.update(dictionary)
    return result

slang_dict = merge_dicts(slang_dict_one, slang_dict_two, slang_dict_three, slang_dict_four)

# %% [markdown]
# ## Replace slang with definitions

# %%
from nltk.corpus import sentiwordnet as swn
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
lemmatizer = WordNetLemmatizer()

# %%
def slang_sentiment(text):
    text = remove_slang(text)
    senti = get_sentiment_text(text)
    return senti

def positive(text, indicator):
    text = remove_slang(text)
    senti = get_sentiment_text(text)
    return get_pos(text, indicator)

def negative(text, indicator):
    text = remove_slang(text)
    senti = get_sentiment_text(text)
    return get_pos(text, indicator)

def objective(text, indicator):
    text = remove_slang(text)
    senti = get_sentiment_text(text)
    return get_pos(text, indicator)

def remove_slang(text):
    s = tknzr.tokenize(text)
    soFar = ''
    
    for word in s: 
        if word.lower() in slang_dict:
            soFar += slang_dict[word.lower()] + ' '
        else:
            soFar += word  + ' ' 
    return soFar.split(' ')

def get_sentiment_text(strList):
    text = ' '.join(strList)
    pos_values = nltk.pos_tag(text)
    pos_senti = []
    for (x, y) in pos_values:
        if len(get_sentiment(x,y)) > 1:
            pos_senti.append(get_sentiment(x,y))
        else: 
            pos_senti.append([0, 0, 0])       
    return pos_senti
        
def get_pos(text, indicator):
    x = 0
    pos = get_sentiment_text(text)
    for v in pos:
        x +=  v[indicator]
    return x

# %%
from nltk.corpus import wordnet as wn

# %%
def penn_to_wn(tag):
#Convert between the PennTreebank tags to simple Wordnet tags"""
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

# %%
def get_sentiment(word,tag):
#""" returns list of pos neg and objective score. But returns empty list if not present in senti wordnet. """
    wn_tag = penn_to_wn(tag)
    if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
        return []

    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    if not lemma:
        return []

    synsets = wn.synsets(word, pos=wn_tag)
    if not synsets:
        return []
    
    # Take the first sense, the most common
    synset = synsets[0]
    swn_synset = swn.senti_synset(synset.name())

    return [swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score()]

# %%
data = pd.read_csv('SentiWordNet_3.0.0.txt', sep='\t', header=None)
data.columns = ["POS","ID","PosScore","NegScore","SynsetTerms","Gloss"]

# %% [markdown]
# Check for quotes

# %%
def contains_quotes(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word == '"' or word == "'" else 0, s))
    if score > 0: 
        return 1 
    return 0

# %% [markdown]
# Check if self-referential

# %%
ethnic_groups = []
with open('ethnic_groups_and_common_slurs.txt', 'r') as fileinput:
    for line in fileinput:
        ethnic_groups.append((line.split('\n'))[0].lower())


#demonstrative adjectives and other words that can inidicate targeting of a specific group
targets = ['all', 'every', 'you', 'those', 'these', 'any', 'each', 'no', 'that', 'this']
modality = ['should', 'can', 'can\'t', 'cannot', 'won\'t', 'will', 'want', 'wants', 'are']
reclaiming = ['proud', 'reclaim', 'reclaming', 'offensive', 'like']
me = ['i\'m', 'we', 'i', 'me', 'this']

def contains_target_self_referential(text):
    words = tknzr.tokenize(text)
                
    #check word in ethnic_groups comes before word in me   
    #e.g. the beaner in me forgets I like beans
    for word in ethnic_groups:
        if word in words[0:]:
            for key in me:
                if key in words[words.index(word):]:
                    return 1
    
    #check if word in me comes before word in reclaiming
    #e.g. i'm a proud beaner
    for key in me:
        if key in words[0:]:
            for word in reclaiming:
                if word in words[words.index(key):]:
                    return 1
                #check if word in me comes before word in ethnic_groups
            for word in ethnic_groups:
                if word in words[words.index(key):]:
                    return 1
            #check if word in me comes before word in ethnic_groups
            #e.g. We beaners have to stick together
            for word in ethnic_groups:
                if word in words[words.index(key):]:
                    return 1
     #check if word in reclaiming comes after modality 
    #e.g. all beaners should go home is offensive
    for key in modality:
        if key in words[0:]:
            for word in reclaiming:
                if word in words[words.index(key):]:
                    return 1
    return 0

# %% [markdown]
# Offensive to women/words that hurt

# %%
words_that_hurt = {
    'bitch': 'Targets and dehumanizes women, even if used toward men, including queer and gay men. Devalues women and femininity. Reinforces sexism.',
    'ghetto' :'Describes something or someone as cheap, worn out, poor, dangerous, etc. Reference to housing communities that are impoverished and disproportionately impact people of color. Associates people of color with these negative characteristics.',
    'ratchett':'Describes something or someone as cheap, worn out, poor, dangerous, etc. Reference to housing communities that are impoverished and disproportionately impact people of color. Associates people of color with these negative characteristics.',
    'illegal alien': 'Reduces undocumented immigrants to something less than human. Fixates on legal status instead of people as individuals. Asserts that some people belong here more than others do. Ignores political, social, and economic factors that impact people of color.',
    'no homo': 'Stresses the speaker\'s heterosexuality, masculinity, and/or other traits to avoid being perceived as LGBTQIA. Goes to great lengths to avoid association with anything queer. Reinforces that to be LGBTQIA is bad.',
    'retarded': 'Targets mental, emotional and physical disabilities as objects for ridicule. Used as synonyms for "worthless," "bad," "unintelligent," "incapable," etc.',
    'retard': 'Targets mental, emotional and physical disabilities as objects for ridicule. Used as synonyms for "worthless," "bad," "unintelligent," "incapable," etc.',
    'lame': 'Targets mental, emotional and physical disabilities as objects for ridicule. Used as synonyms for "worthless," "bad," "unintelligent," "incapable," etc.',
    'crazy':'Targets mental, emotional and physical disabilities as objects for ridicule. Used as synonyms for "worthless," "bad," "unintelligent," "incapable," etc.',
    'dumb': 'Targets mental, emotional and physical disabilities as objects for ridicule. Used as synonyms for "worthless," "bad," "unintelligent," "incapable," etc.',
    'that\'s so gay': 'Stigmatizes gay and queer people. Uses their identities to describe something as undesirable and bad. Replaces negative adjectives with words related to LGBTQIA identities.',
    'whore': 'Dismisses anyone seen as being "too" sexual, particularly sex workers, women, LGBTQI people and people of color. Perpetuates negativity toward sex itself. Regulates who is allowed to have it.',
    'ho': 'Dismisses anyone seen as being "too" sexual, particularly sex workers, women, LGBTQI people and people of color. Perpetuates negativity toward sex itself. Regulates who is allowed to have it.',
    'slut': 'Dismisses anyone seen as being "too" sexual, particularly sex workers, women, LGBTQI people and people of color. Perpetuates negativity toward sex itself. Regulates who is allowed to have it.',
    'Bisexuality doesn\'t really exist. People are just gay or straight.': 'This denies the fluidity of sexuality and dismisses people\'s experiences and definitions of self. People deserve the right to define their own identities any way they wish and have those definitions honored.',
    'i think everyone is bisexual': 'While this is often meant to acknowledge the fluidity of sexuality, it dismisses the reality of people who identify as bisexual and erases their experiences. It also invalidates the self-identifications of non-bisexual people.',
    'You\'re too femme to be bisexual':'Gender presentation does not indicate sexual orientation. Bisexual people have a wide range of gender presentations.',
    'You\'re too butch to be bisexual':'Gender presentation does not indicate sexual orientation. Bisexual people have a wide range of gender presentations.',
    'Bisexual people just want straight privilege':'Bisexual people experience discrimination within straight communities and lesbian/gay communities. They never fully experience straight privilege because they do not identify as straight. Often their identities are made invisible and denied.',
    'Bisexual people are just greedy and want to have sex with everyone.':'This stereotypes bisexual people and assumes they are all promiscuous - and that this is a bad thing. It creates negative attitudes toward sex and works against creating a sex positive climate. It also demonstrates an underlying belief that bisexuality is only about behavior and is not a legitimate identity.',
    'Who do you see yourself ending up with?':'This is another way of implying one has to "end up" gay or straight and ignores bisexuality as an identity versus a relationship status. It also assumes everyone desires to be in a long-term monogamous relationship.',
    'Tranny':'Whether or not someone identifies as trans*, calling anyone "tranny" is extremely offensive. While some folks within the trans* community may choose to reclaim this word for themselves, it is not a word that is okay to use to label another person or use as a joke.',
    'That person doesn\'t really look like a woman':'What does it mean to look like a man or woman? There are no set criteria. It also should not be assumed that all Trans Men strive to fit within dominant ideas of masculinity or all Trans Women strive to fit within dominant ideas of femininity, or that all Trans* people want to look like men or women. Gender presentation is fluid and distinct from gender identity, and all forms of gender expression deserve affirmation.',
    'That person doesn\'t really look like a man':'What does it mean to look like a man or woman? There are no set criteria. It also should not be assumed that all Trans Men strive to fit within dominant ideas of masculinity or all Trans Women strive to fit within dominant ideas of femininity, or that all Trans* people want to look like men or women. Gender presentation is fluid and distinct from gender identity, and all forms of gender expression deserve affirmation.',
    'What is your REAL name? I mean the one you were given at birth':'This implies that the person\'s gender identity and chosen name are not "real" and perpetuates the idea of Trans people as deceptive. It removes agency and any right to make decisions for themselves, and is incredibly invalidating. It presumes a right to intimate information, disregards privacy, and places Trans lives on public display.',
    'He-She':'This hyphenated term is demeaning and invalidates an individual\'s identity and the pronouns that they use.',
    'What are you REALLY? Have you had surgery?': 'Asking anyone personal questions about their bodies and/or surgeries is invasive and inappropriate. We don\'t ask cisgender people about what is under their clothes; we shouldn\'t ask Trans* people either.',
    'cunt':'Using words that refer to people with vaginas to express that someone is weak or emotional. Dehumanizes womxn and perpetuates misogyny and sexism.',
    'twat':'Using words that refer to people with vaginas to express that someone is weak or emotional. Dehumanizes womxn and perpetuates misogyny and sexism.',
    'pussy':'Using words that refer to people with vaginas to express that someone is weak or emotional. Dehumanizes womxn and perpetuates misogyny and sexism.',
    'thot':'Word created to express womxn or people who are sexually promiscuous. There are speculations that the word comes from the KKK organization that referred to Black women who were forced into prostitution (i.e. Sarah Baartman: Hottentot).',
    'ugly':'Word used to put down someone for the way they look, can be connected back to white supremacist, ableist, sizeist standards of beauty.',
    'you guys':'Erases the identities of people who are in the room. Generalizing a group of people to be masculine.',
    'I\'m being such a fat-ass':'Demeans and devalues fatness/fat bodies, reinforces harmful assumptions that fat people are gluttonous and are fat because they have no restraint around food. Also implies that there is an acceptable amount of food to eat and anything more is disgusting, or that enjoying food too much is disgusting.',
    'I\'m being so fat right now!':'Demeans and devalues fatness/fat bodies, reinforces harmful assumptions that fat people are gluttonous and are fat because they have no restraint around food. Also implies that there is an acceptable amount of food to eat and anything more is disgusting, or that enjoying food too much is disgusting.'
}

hurtfulWords = list(words_that_hurt.keys())

# %%
#Binary Feature #6 1) ID tweets with female pronouns 2) Check if these words are in the tweet 

#these words are used disproportionately often against women
#the behaviour they describe often goes unremarked in men.
#source: http://sacraparental.com/2016/05/14/everyday-misogyny-122-subtly-sexist-words-women/
#EVERYDAY MISOGYNY: 122 SUBTLY SEXIST WORDS ABOUT WOMEN (AND WHAT TO DO ABOUT THEM)
female_and_nongender_Pronouns = set(['you','she','its','their','yours',
                                    'her', 'it', 'they', 'them',
                                    'yourself', 'herself', 'themselves',
                                    'your','hers'])

pronouns = {'I': ('personal', True, 'first'),
 'me': ('personal', True, 'first'),
 'we': ('personal', False, 'first'),
 'us': ('personal', False, 'first'),
 'you': ('personal', False, 'second'),
 'she': ('personal', True, 'third'),
 'he': ('personal', True, 'third'),
 'her': ('possessive', True, 'third'),
 'him': ('personal', True, 'third'),
 'it': ('personal', True, 'third'),
 'they': ('personal', False, 'third'),
 'them': ('personal', False, 'third'),
 'myself': ('reflexive', True, 'first'),
 'ourselves': ('reflexive', False, 'first'),
 'yourself': ('reflexive', True, 'second'),
 'yourselves': ('reflexive', False, 'second'),
 'himself': ('reflexive', True, 'third'),
 'herself': ('reflexive', True, 'third'),
 'itself': ('reflexive', True, 'third'),
 'themselves': ('reflexive', False, 'third'),'my': ('possessive', True, 'first'),
 'your': ('possessive', False, 'second'),
 'his': ('possessive', True, 'third'),
 'hers': ('possessive', True, 'third'),
 'its': ('possessive', True, 'third'),
 'our': ('possessive', False, 'first'),
 'their': ('possessive', False, 'third'),
 'mine': ('possessive', True, 'first'),
 'yours': ('possessive', False, 'second'),
 'ours': ('possessive', False, 'first')}

female_offensive = ['bossy', 'abrasive', 'ball-buster', 'aggressive', 
'shrill', 'bolshy', 'intense', 'stroppy', 'forward', 
'mannish', 'gossipy', 'Dramatic', 'Drama Queen', 'Catty', 
'Bitchy', 'Nag', 'Cold', 'Ice queen', 'Shrew', 'Humourless',
'Man-hater', 'Banshee', 'Fishwife', 'Lippy', 'Ditzy', 'Feminazi', 
'militant feminist', 'Bridezilla', 'Diva', 'Prima donna', 'Blonde moment',
'Feisty', 'Supermum','Working mother', 'Career woman', 'Yummy mummy', 'Little old lady', 
'WAHM', 'Slut', 'Trollop','Frigid','Easy','Tease','Loose','Man-eater','Cougar',
'Asking for it','prude','the town bike', 'Mutton dressed as lamb','Slutty','Curvy','Mumsy',
'Cheap','That dress is flattering','Frumpy','Let herself go','Faded beauty','Mousey',
 'Plus-size','Clotheshorse','Brunette ','Ladylike','Bubbly','Vivacious','Flirty',
'Sassy','Chatty','Demure','Modest','Emotional','Hysterical','Hormonal',
'Menstrual ',' pre-menstrual ','Flaky','Moody','Over-sensitive',
'Clucky','Neurotic','Irrational','Baby brain','Baby weight','Mummy blogger',
'Female engineer','That’s good, for a girl','Like a girl','run like a girl', 
'throw like a girl','Mumpreneur','Spinster','Barren','She wears the pants','Housewife',
'Houseproud','Soccer mom','Mistress','Kept woman','Incompetent cervix',
'Failure to progress','Elderly primagravida','Irritable uterus','Tomboy',
'Girly','a girly girl','Little lady','Jail-bait','Heart-breaker','pretty little thing','Catfight','Mommy wars','Caring','Compassionate','Hard-working',
'Conscientious','Dependable','Diligent','Dedicated','Tactful','Interpersonal','Warm',
'Helpful','Maternal', 'Princess', 'Heart-breaker']
#most tweeted to Megyn Kelly by Trump and trump supporters
#https://www.vox.com/2016/1/27/10852876/donald-trump-supporters-sexist-tweets-megyn-kelly
trump_suppporters_megynKelly = ["ugly", "cheap", 'bitch', 'whore', 'bimbo',
                                'cunt', 'hooker', 'slut', 'skank']
others = ['hoe', 'pussy', 'bitches', 'fatty', 'fatass', 'fat-ass']
offsensive_words_toward_women = female_offensive + trump_suppporters_megynKelly + others + hurtfulWords

# %%
female_offensive_words = set()
for word in offsensive_words_toward_women:
    female_offensive_words.add(word.lower())
#female_offensive_words

def check_offensive_to_women(text):
    #split tweet by white space and make lower case
    li = set([word.lower() for word in text.split()]) 
    isFemale = female_and_nongender_Pronouns.intersection(li)
    if len(isFemale) == 0:
        return 0
    isOffensive = female_offensive_words.intersection(li)
    if isOffensive:
        return len(isOffensive)
    return 0

# %% [markdown]
# NRC emotions

# %%
nrc_emotions_df = pd.read_csv("nrc_emotions.csv")

# %%
anger = nrc_emotions_df.loc[nrc_emotions_df['anger']][['term']].values
anticipation = nrc_emotions_df.loc[nrc_emotions_df['anticipation']][['term']].values
disgust = nrc_emotions_df.loc[nrc_emotions_df['disgust']][['term']].values
fear = nrc_emotions_df.loc[nrc_emotions_df['fear']][['term']].values
joy = nrc_emotions_df.loc[nrc_emotions_df['joy']][['term']].values
sadness = nrc_emotions_df.loc[nrc_emotions_df['sadness']][['term']].values
surprise = nrc_emotions_df.loc[nrc_emotions_df['surprise']][['term']].values
trust = nrc_emotions_df.loc[nrc_emotions_df['trust']][['term']].values

# %%
def anger_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in anger else 0, s))
    return score

# %%
def anticipation_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in anticipation else 0, s))
    return score

# %%
def disgust_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in disgust else 0, s))
    return score

# %%
def joy_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in joy else 0, s))
    return score

# %%
def fear_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in fear else 0, s))
    return score

# %%
def sadness_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in sadness else 0, s))
    return score

# %%
def surprise_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in surprise else 0, s))
    return score

# %%
def trust_count(text):
    s = tknzr.tokenize(text)
    score = sum(map(lambda word : 1 if word in trust else 0, s))
    return score

# %%
#groups = open('groups.txt','r').read().split('\n')
ethnic_groups = []
with open('ethnic_groups_and_common_slurs.txt', 'r') as fileinput:
    for line in fileinput:
        ethnic_groups.append((line.split('\n'))[0].lower())
#demonstrative adjectives and other words that can inidicate targeting of a specific group
targets = ['all', 'every', 'you', 'those', 'these', 'any', 'each', 'no', 'that', 'this', ]
modality = ['should', 'can', 'can\'t', 'cannot', 'won\'t', 'will', 'want']

# %%
#If tweet contains a targeted statement referring to a certain group, i.e. "all you Asians" or "every Mexican"
#also checks if a group word is followed by some sort of modal verb

def contains_target(text):
    s = tknzr.tokenize(text)
    
    for i in range(len(s)):
        if s[i].lower() in targets:
            if i != len(s)-1:
                if s[i+1].lower() in ethnic_groups:
                    return 1
            
        elif s[i].lower() in ethnic_groups:
            if i != len(s)-1:
                if s[i+1].lower() in modality:
                    return 1            
        return 0

# %%
def other_features_base(tweet):
    words = preprocess(tweet) #Get text only
    
    syllables = textstat.syllable_count(words)
    num_chars = sum(len(w) for w in words)
    num_chars_total = len(tweet)
    num_terms = len(tweet.split())
    num_words = len(words.split())
    avg_syl = round(float((syllables+0.001))/float(num_words+0.001),4)
    num_unique_terms = len(set(words.split()))
    
    ###Modified FK grade, where avg words per sentence is just num words/1
    FKRA = round(float(0.39 * float(num_words)/1.0) + float(11.8 * avg_syl) - 15.59,1)
    ##Modified FRE score, where sentence fixed to 1
    FRE = round(206.835 - 1.015*(float(num_words)/1.0) - (84.6*float(avg_syl)),2)
    
    twitter_objs = count_twitter_objs(tweet)
    retweet = 0
    if "rt" in words:
        retweet = 1
    features = [num_chars, num_chars_total, num_terms, num_words,
                num_unique_terms,
                twitter_objs[2], twitter_objs[1],
                twitter_objs[0], retweet]
    #features = pandas.DataFrame(features)
    return features
    
def other_features(tweet):
    """This function takes a string and returns a list of features.
    These include Sentiment scores, Text and Readability scores,
    as well as Twitter specific features"""
    #sentiment = sentiment_analyzer.polarity_scores(tweet)
    
    #Our features
    text_only = preprocess(tweet) #Get text only
    words = remove_slang(text_only) #replace slang/abbreviations with full words 
    
    senti = slang_sentiment(text_only)
    pos = positive(tweet, 0)
    neg = negative(tweet, 1)
    obj = objective(tweet, 2)
    
    no_slang_str = ''.join(words)
    trustCount = trust_count(no_slang_str)
    surpriseCount = surprise_count(no_slang_str)
    sadnessCount = sadness_count(no_slang_str)
    fearCount = fear_count(no_slang_str)
    joyCount = joy_count(no_slang_str)
    disgustCount = disgust_count(no_slang_str)
    anticipationCount = anticipation_count(no_slang_str)
    angerCount = anger_count(no_slang_str)
    isSelfReferential = contains_target_self_referential(no_slang_str)
    hasQuotes = contains_quotes(tweet)
    targeted = contains_target(text_only)
    immigrant_ref = 0
    if text_only.find('immigrant') or text_only.find('immigrants'):
        immigrant_ref = 1
    isOffensiveToWomen = check_offensive_to_women(tweet)
    
    #Davidson features
    syllables = textstat.syllable_count(text_only)
    num_chars = sum(len(w) for w in text_only)
    num_chars_total = len(tweet)
    num_terms = len(tweet.split())
    num_words = len(tweet.split())
    #avg_syl = round(float((syllables+0.001))/float(num_words+0.001),4)
    num_unique_terms = len(set(text_only.split()))
    
    twitter_objs = count_twitter_objs(tweet)
    retweet = 0
    if "rt" in words:
        retweet = 1
        
    features = [num_chars, num_chars_total, num_terms, num_words,
                num_unique_terms,
                twitter_objs[2], twitter_objs[1],
                twitter_objs[0], retweet, targeted, immigrant_ref, isOffensiveToWomen,
                trustCount, surpriseCount, sadnessCount, angerCount, fearCount, 
                joyCount, disgustCount, anticipationCount, isSelfReferential, hasQuotes, pos, neg, obj]
   
    return features

def get_feature_array(tweets, base):
    feats=[]
    for t in tweets:
        if base:
            feats.append(other_features_base(t))
        else:
            feats.append(other_features(t))
    return np.array(feats)

# %%
other_features_names = ["num_chars", "num_chars_total", "num_terms", "num_words", "num_unique_words", "num_hashtags", \
                    "num_mentions", "num_urls", "is_retweet", "targeted", "immigrant_ref", "isOffensiveToWomen",
                "trustCount", "surpriseCount", "sadnessCount", "angerCount", "fearCount", 
              "joyCount", "disgustCount", "anticipationCount", "isSelfReferential", "hasQuotes", "pos", "neg", "obj"]

other_features_base_names = ["num_chars", "num_chars_total", "num_terms", "num_words", "num_unique_words", "num_hashtags", \
                    "num_mentions", "num_urls", "is_retweet"]

# %%
base_feats = get_feature_array(tweets, True)

# %%
hand_built_feats = get_feature_array(tweets, False)

# %% [markdown]
# ## Flair

# %%
from flair.embeddings import DocumentPoolEmbeddings, WordEmbeddings, CharacterEmbeddings, StackedEmbeddings, FlairEmbeddings, BertEmbeddings
import torch

# %%
#stack word-level twitter embeddings and forward/backward flair sentence embeddings
news_forward = FlairEmbeddings('news-forward-fast')
news_backward = FlairEmbeddings('news-backward-fast')
twitter = WordEmbeddings('twitter')
bert = BertEmbeddings('bert-base-uncased')
#elmo = ELMoEmbeddings('small')

# %%
from flair.data import Sentence

# %% [markdown]
# Create embedding for tweets by getting token-level embeddings from stacked embedding

# %%
import time, sys
from IPython.display import clear_output
def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1
        
    block = int(round(bar_length * progress))
    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
def embed_tweets(model, row_len, tweets):
    embeddings = np.empty([len(tweets), row_len])
    num = 0
    total = len(tweets)
    for tweet in tweets:
        s = Sentence(tweet)
        model.embed(s)
        flattened = np.array(s.get_embedding().detach()).flatten()
        #print(flattened.shape[0])
        embeddings[num] = (flattened)
        num+=1
        update_progress(num / total)

    update_progress(1)
    return embeddings

# %%
#tweet_embed = DocumentPoolEmbeddings([twitter])

# %%
#%%time
#tweet_embeddings = embed_tweets(tweet_embed,100)
#np.savetxt('tweet_embeddings.txt', tweet_embeddings)

tweet_embeddings = np.loadtxt('tweet_embeddings.txt')

# %%
#bert_embed = DocumentPoolEmbeddings([bert])

# %%
#%%time
#bert_embeddings = embed_tweets(bert_embed, 3072)
#np.savetxt('bert_embeddings.txt', bert_embeddings)

#bert_embeddings = np.loadtxt('bert_embeddings.txt')

# %%
bert_news_twitter_embed = DocumentPoolEmbeddings([news_forward, news_backward, bert, twitter])

# %%
#bert_news_twitter_embeddings = embed_tweets(bert_news_twitter_embed, 5220)
#np.savetxt('bert_news_twitter_embeddings.txt', bert_news_twitter_embeddings)

bert_news_twitter_embeddings = np.loadtxt('bert_news_twitter_embeddings.txt')

# %% [markdown]
# ## Train Models with features

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline

# %% [markdown]
# Flair embeddings

# %%
#Now join them all up
M1 = np.concatenate([tfidf,pos,base_feats,bert_news_twitter_embeddings],axis=1)

# %%
#M2 = np.concatenate([tfidf,pos,feats,bert_embeddings],axis=1)
M3 = np.concatenate([tfidf,pos,base_feats,tweet_embeddings],axis=1)

# %% [markdown]
# Hand-built features

# %%
M4 = np.concatenate([tfidf,pos,hand_built_feats],axis=1)

# %% [markdown]
# Combine hand-built and twitter embeddings

# %%
M5 = np.concatenate([tfidf,pos,hand_built_feats,tweet_embeddings],axis=1)

# %%
M6 = np.concatenate([tfidf,pos,hand_built_feats,bert_news_twitter_embeddings],axis=1)

# %% [markdown]
# ## Train

# %%
def train_model(M):
    X = pd.DataFrame(M)
    y = df['class'].astype(int)
    pipe = Pipeline(
        [('select', SelectFromModel(LogisticRegression(class_weight='balanced',
                                                  penalty="l1", C=0.01))),
        ('model', LogisticRegression(class_weight='balanced',penalty='l2'))])
    param_grid = [{}] # Optionally add parameters here
    grid_search = GridSearchCV(pipe, 
                           param_grid,
                           cv=StratifiedKFold(n_splits=5, 
                                              random_state=42).split(X, y), 
                           verbose=2)
    model = grid_search.fit(X, y)
    return model

# %%
tweet_only_LR = train_model(M3)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................................. , total=  26.3s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   26.6s remaining:    0.0s
# [CV] ................................................. , total=  12.4s
# [CV]  ................................................................
# [CV] ................................................. , total=  11.4s
# [CV]  ................................................................
# [CV] ................................................. , total=  13.2s
# [CV]  ................................................................
# [CV] ................................................. , total=  11.6s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.3min finished

# %%
# np.savetxt("tweet_only_true.txt", tweet_only_true)
# np.savetxt("tweet_only_pred.txt", tweet_only_pred)

# %%
#bert_only_true, bert_only_pred, bert_only_model = train_model(M2)

# %%
# np.savetxt("bert_only_true.txt", bert_only_true)
# np.savetxt("bert_only_pred.txt", bert_only_pred)

# %%
bert_news_twitter_model = train_model(M1)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................................. , total=29.2min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 29.2min remaining:    0.0s
# [CV]  ................................................................
# [CV] ................................................. , total=46.6min
# [CV]  ................................................................
# [CV] ................................................. , total=16.8min
# [CV]  ................................................................
# [CV] ................................................. , total=26.3min
# [CV]  ................................................................
# [CV] ................................................. , total=28.0min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 147.2min finished

# %%
# np.savetxt("bert_news_twitter_true.txt", bert_news_twitter_true)
# np.savetxt("bert_news_twitter_pred.txt", bert_news_twitter_pred)

# %%
hand_built_model = train_model(M4)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................................. , total=  16.2s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.5s remaining:    0.0s
# [CV] ................................................. , total=  10.5s
# [CV]  ................................................................
# [CV] ................................................. , total=   9.3s
# [CV]  ................................................................
# [CV] ................................................. , total=   9.0s
# [CV]  ................................................................
# [CV] ................................................. , total=  10.1s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   56.2s finished

# %%
# np.savetxt("hand_built_true.txt", hand_built_true)
# np.savetxt("hand_built_pred.txt", hand_built_pred)

# %%
combined_model = train_model(M5)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................................. , total=  41.7s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   41.9s remaining:    0.0s
# [CV] ................................................. , total=  12.6s
# [CV]  ................................................................
# [CV] ................................................. , total=  11.7s
# [CV]  ................................................................
# [CV] ................................................. , total=  10.5s
# [CV]  ................................................................
# [CV] ................................................. , total=  13.8s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.5min finished

# %%
bnt_hb_combined_model = train_model(M6)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................................. , total=34.2min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 34.3min remaining:    0.0s
# [CV]  ................................................................
# [CV] ................................................. , total=25.8min
# [CV]  ................................................................
# [CV] ................................................. , total=41.0min
# [CV]  ................................................................
# [CV] ................................................. , total=20.9min
# [CV]  ................................................................
# [CV] ................................................. , total=29.7min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 151.8min finished

# %% [markdown]
# ## Training Evaluation

# %%
all_tweets = df[['tweet', 'class']]

# %%
def evaluate(y_true, y_preds, tweet):
    report = classification_report( y_true, y_preds )
    print(report)
    
    misses = np.where(np.asarray(y_true) != y_preds)
    missed_preds = []
    for i in range(len(y_true)):
        if np.asarray(y_true)[i] != y_preds[i]:
            missed_preds.append(y_preds[i])


    missed = [list(y_true.index)[i] for i in misses[0]]
    missed_tweets = tweet.iloc[missed]
    missed_tweets.loc[:,'prediction'] = missed_preds
    
    corrects = np.where(np.asarray(y_true) == y_preds)
    correct_preds = []
    for i in range(len(y_true)):
        if np.asarray(y_true)[i] == y_preds[i]:
            correct_preds.append(y_preds[i])


    correct = [list(y_true.index)[i] for i in corrects[0]]
    correct_tweets = tweet.iloc[correct]
    correct_tweets.loc[:,'prediction'] = correct_preds
    return missed_tweets, correct_tweets

# %% [markdown]
# Tweet sentence embeddings

# %%
tweet_missed = evaluate(tweet_only_true, tweet_only_pred, all_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.44      0.36       104
#            1       0.94      0.88      0.91      1507
#            2       0.75      0.83      0.79       364
#
#    micro avg       0.85      0.85      0.85      1975
#    macro avg       0.66      0.72      0.68      1975
# weighted avg       0.87      0.85      0.86      1975

# %% [markdown]
# BERT embeddings

# %%
bert_missed = evaluate(bert_only_true, bert_only_pred, all_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.44      0.37       104
#            1       0.94      0.89      0.91      1507
#            2       0.77      0.84      0.80       364
#
#    micro avg       0.86      0.86      0.86      1975
#    macro avg       0.67      0.72      0.69      1975
# weighted avg       0.87      0.86      0.87      1975

# %% [markdown]
# Combined BERT, news, and tweet embeddings

# %%
bert_news_twitter_missed = evaluate(bert_news_twitter_true, bert_news_twitter_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.34      0.45      0.39       104
#            1       0.94      0.89      0.92      1507
#            2       0.78      0.86      0.82       364
#
#    micro avg       0.86      0.86      0.86      1975
#    macro avg       0.69      0.73      0.71      1975
# weighted avg       0.88      0.86      0.87      1975

# %%
hand_built_missed = evaluate(hand_built_true, hand_built_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.41      0.33       104
#            1       0.92      0.86      0.89      1507
#            2       0.68      0.77      0.72       364
#
#    micro avg       0.82      0.82      0.82      1975
#    macro avg       0.62      0.68      0.65      1975
# weighted avg       0.84      0.82      0.83      1975
# /anaconda2/envs/nlu/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /anaconda2/envs/nlu/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
both_missed = evaluate(combined_true, combined_pred)

# %% [markdown]
# ## Run on test set

# %%
testing = pd.read_csv("data/test/testing_data.csv")
dev = pd.read_csv("data/dev/development_data.csv") #dev wasn't used in training
test = pd.concat([testing, dev], sort=False)

# %%
y_test = test['class'].astype(int)

# %%
test_tweets = test['tweet']

# %%
#use transform instead of fit_transform to get vector in same space as training data
test_tfidf = vectorizer.transform(test_tweets).toarray()

# %%
test_tweet_tags = []
for t in test_tweets:
    tokens = basic_tokenize(preprocess(t))
    tags = nltk.pos_tag(tokens)
    tag_list = [x[1] for x in tags]
    tag_str = " ".join(tag_list)
    test_tweet_tags.append(tag_str)

# %%
test_pos = pos_vectorizer.transform(pd.Series(test_tweet_tags)).toarray()

# %%
base_test_feats = get_feature_array(test_tweets, True)

# %%
hand_built_test_feats = get_feature_array(test_tweets, False)

# %% [markdown]
# Test tweet only embeddings

# %%
tweet_embed = DocumentPoolEmbeddings([twitter])

# %%
test_tweet_embeddings = embed_tweets(tweet_embed,100, test_tweets)
# Out:
# Progress: [####################] 100.0%

# %%
test_M3 = np.concatenate([test_tfidf,test_pos,base_test_feats,test_tweet_embeddings],axis=1)

# %%
tweet_only_preds = tweet_only_LR.predict(test_M3)

# %% [markdown]
# Test hand-built features

# %%
test_M4 = np.concatenate([test_tfidf,test_pos,hand_built_test_feats],axis=1)

# %%
hand_built_preds = hand_built_model.predict(test_M4)

# %% [markdown]
# Test combined hand-built and tweet embeddings

# %%
test_M5 = np.concatenate([test_tfidf,test_pos,hand_built_test_feats,test_tweet_embeddings],axis=1)

# %%
combined_preds = combined_model.predict(test_M5)

# %% [markdown]
# Bert, news, and twitter embeddings

# %%
test_bert_news_twitter_embeddings = embed_tweets(bert_news_twitter_embed, 5220, test_tweets)
# Out:
# Progress: [################----] 78.6%

# %%
#test_bert_news_twitter_embeddings.shape, bert_news_twitter_embeddings.shape,

# %%
#test_tfidf.shape, tfidf.shape,test_pos.shape, pos.shape,base_test_feats.shape, base_feats.shape

# %%
test_M1 = np.concatenate([test_tfidf,test_pos,base_test_feats,test_bert_news_twitter_embeddings],axis=1)

# %%
test_M1.shape, M1.shape
# Out:
# ((4937, 9046), (19746, 9046))

# %%
bert_news_twitter_preds = bert_news_twitter_model.predict(test_M1)

# %% [markdown]
# Bert, news, and twitter embeddings with hand-built features

# %%
test_M6 = np.concatenate([test_tfidf,test_pos,hand_built_test_feats,test_bert_news_twitter_embeddings ],axis=1)

# %%
bnt_hb_combined_preds = bnt_hb_combined_model.predict(test_M6)

# %% [markdown]
# ## Test Evaluation

# %%
testing_tweets = test[['tweet','class']]

# %%
test_tweet_only_missed, test_tweet_only_correct = evaluate(y_test, tweet_only_preds, testing_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.35      0.29       265
#            1       0.92      0.87      0.90      3875
#            2       0.68      0.75      0.71       797
#
#    micro avg       0.83      0.83      0.83      4937
#    macro avg       0.62      0.66      0.63      4937
# weighted avg       0.84      0.83      0.83      4937

# %%
test_hand_built_missed, test_hand_built_correct = evaluate(y_test, hand_built_preds, testing_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.36      0.29       265
#            1       0.91      0.86      0.89      3875
#            2       0.65      0.71      0.68       797
#
#    micro avg       0.81      0.81      0.81      4937
#    macro avg       0.60      0.64      0.62      4937
# weighted avg       0.83      0.81      0.82      4937

# %%
test_combined_missed, test_combined_correct = evaluate(y_test, combined_preds, testing_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.38      0.32       265
#            1       0.92      0.87      0.90      3875
#            2       0.68      0.75      0.71       797
#
#    micro avg       0.83      0.83      0.83      4937
#    macro avg       0.62      0.67      0.64      4937
# weighted avg       0.85      0.83      0.84      4937

# %%
test_bert_news_twitter_missed, test_bert_news_twitter_correct = evaluate(y_test, bert_news_twitter_preds, testing_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.47      0.38       265
#            1       0.95      0.88      0.91      3875
#            2       0.74      0.85      0.79       797
#
#    micro avg       0.86      0.86      0.86      4937
#    macro avg       0.67      0.74      0.69      4937
# weighted avg       0.88      0.86      0.87      4937

# %%
test_bnt_hb_combined_missed, test_bnt_hb_combined_correct = evaluate(y_test, bnt_hb_combined_preds, testing_tweets)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.47      0.38       265
#            1       0.95      0.89      0.92      3875
#            2       0.74      0.84      0.79       797
#
#    micro avg       0.86      0.86      0.86      4937
#    macro avg       0.67      0.73      0.69      4937
# weighted avg       0.88      0.86      0.87      4937

# %%
combined_missed.to_csv("test_tweet_hand_combined_missed.csv", sep='\t')

# %%
test_hand_built_missed.to_csv("test_hand_built_missed.csv", sep='\t')

# %%
test_tweet_only_missed.to_csv("test_tweet_only_missed.csv", sep='\t')

# %%
test_bert_news_twitter_missed.to_csv("test_bert_news_twitter_missed.csv", sep='\t')

# %%
test_bnt_hb_combined_missed.to_csv("test_bnt_hb_combined_missed.csv", sep='\t')

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 700)

# %%
test_bnt_hb_combined_correct_hate = test_bnt_hb_combined_correct.loc[test_bnt_hb_combined_correct['class']==2][['tweet']]

# %%
test_bnt_hb_combined_correct_hate.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-548-6c927e81c1c7> in <module>
# ----> 1 test_bnt_hb_combined_correct_hate.columns = ['id', 'tweet']
#
# /anaconda2/envs/nlu/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /anaconda2/envs/nlu/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# /anaconda2/envs/nlu/lib/python3.7/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3321             raise ValueError(
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#    3325         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 2 elements

# %%
test_bnt_hb_combined_correct_hate
# Out:
#                                                                                                                                                                              tweet
# 18    RT @DamnFoodPorn: Oreo Cookie Pancakes #FoodPorn http://t.co/q6EvCvM3sO
# 35    Fairy Tale Hat - free crochet pattern for child and adult at http://t.co/0lRaBLMHB2 http://t.co/99zVbmYVe9
# 58    RT @daraobriain: Tommy Voeckler keeps the yellow, Andy Schleck does the break of the tour, and Contador is broken. Incredible day for #tdf
# 63    Watching #Steelers colts getting blinded by the Steelers uniys look like bunch of bumblebees
# 65    RT @netflix: Here's your first look at Charlie Cox as Matt Murdock in #Marvel's @Daredevil on #Netflix #NYCC http://t.co/SIYuCgok8J
# 67    It's a matter of pure weight ratios... A five ounce bird can not carry a one pound coconut!
# 78    Ravioli stuffed wit lobster nd a nice stuffed clam #eating betterthanamobster http://t.co/PzdoESaR
# 80    @AB_crispyy_andy I laugh Oreos and lady gaga on a Sunday day
# 100   #Yankees Damn. Well Joe that move to the bullpen really helped.
# 103   Next time you leave magic trash in my jacket try not to have your initials written on them. @whatupag http://t.co/tFV1cZtr
# 122   Yankees getting killed
# 132   Islamic Jihadis run away to Pakistan @PureMonotheist @BemetOr8 #UniteBlue
# 140   RT @Shalewis09: Larry Elder is an Uncle Tom. I cannot believe how he is degrading a child.
# 168   RT @koolestbreeze: Thanks Charlie!! http://t.co/iw06cCEkND
# 175   @rochaaxx yellow
# 176   RT @HoodJesusYo: Last name, Sinner\nFirst name, Imma\nLike ur pancakes in tha mornin, \nHe got u covered like Aunt Jemima
# 179   RT @chilltweetss: when I make the paper ball into the trash can &#128168; http://t.co/Xnx2XEGACm
# 185   Jay Z - Takeover &amp; U Don't Know LIVE @ Home &amp; Home Concert Yankee Stadium: http://t.co/4EuK80uLiS via @YouTube
# 187   Noap. Not taking them. RT @TiffNCompany: Maca root pills making my vagina do the wop
# 190   @_BradleyC skate 2 trash :(:( skate 3 had goat DLC
# 205   @JonnieSantana He's definitely trash. But if Bill Cohwer or Stanford 's head coach want the job I'd hire them. With a new gm of course
# 213   This Charlie Murder game is pretty dope #Xbla
# 215   RT @TomBradysEgo: Might have a better chance if we put some trash cans out there.
# 219   @Buckm00se @LEXXX_RUGER @ivanrabago_ the kikes want to charge you &#128175; dollaz for the complete version http://t.co/ZJDLwiAjEo
# 223   @louiev_ lol just getting this..early bird catches the worm!
# 228   @XxminijokerXx I HATE birds! They just piss me off about the fact that I can't fly!
# 234   bae won his game &#128525; #redskins
# 246   Oriental rugs cause I'm flyer than a dove.
# 249   @washingtonpost The people who work at those companies tend to be trash.
# 254   RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;
# 264   RT @NickSwagyPYoung: Happy Halloween from Rick James (aka Swaggy) and Charlie Murphy ( @bigmeat2000 ) haha darkness everybody http://t.co/y&#8230;
# 265   RT @MaryWCVB: Still waiting for Charlie Baker to take the stage in Swampscott. #wcvb http://t.co/lYb3Thm199
# 297   Tuna is good the rest trash RT @AyeoFool: Cans of spam RT @MsBTxo: Most struggle food HAS TO BE any meat In a can, tuna included
# 302   RT @CHlLDHOODRUINER: she paid $5 to hold the monkey and look what he did &#128514;&#128557;&#128553; this monkey real af http://t.co/NgeCuWehHb
# 307   We over here struggling with college and work and ice jj fish making money for being trash lol. What has this world come to.
# 313   First jig of the night
# 315   RT @sportswithjohn: Dani Alves uses his new gray hair to talk himself out of a yellow card, telling the referee, "I am but a humble senior &#8230;
# 318   "@UberFacts: 15 sad TV character deaths we're still bitter over... http://t.co/uLclFUF8nC http://t.co/1RXYQOOsM0"ned stark was the man
# 319   MT: "@DocKozlowski: Ted Cruz "We are proud wacko birds". #StandWithCruz #KeepCruzing" is that a pun?
# 330   RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0
# 332   @hxhsharingan666 did you make an animal cracker taco
# 334   can my cat not kill birds and make a huge mes of feathers
# 336   No more speculation. No more mock drafts. It's finally Draft Day. #BortlesKombat #StormWarning #BuiltByUCF #ChargeOn
# 341   @OldManRo you should check it out... it aint animated and has Charlie Murphy in it
# 365   @wodaeeex3 it didnt open das y i asked cus i thought yu ate wat i had Pork chops yellow rice n beans
# 373   Early worm gets the bird #Bslfe #GoodMorning http://t.co/dfE8MF2Q28
# 381   I ate a monkey. #AndNowIHaveEbola
# 383   Charlie Rangel: Some Republicans 'Believe That Slavery Isn't Over' | Truth Revolt: http://t.co/NpbdPk0Cqz \nBam, Race Card Vote Democrats out
# 391   RT @RudeBoi_Drew: @PAPER_CHAYSIN condom were invent for that sole purpose
# 399   Whoever mocks the poor insults his Maker; he who is glad at calamity will not go unpunished. http://t.co/P7zwAoXi4l
# 401   RT @MindOnSuccess_: My mother be on some trash man &#128514; I ask her EVERYDAY, you need/ want some money? She say "Naw I'm good!" But come payday&#8230;
# 402   RT @Macbeth870: #bowebergdahl There hasn't been a trade this lopsided since Babe Ruth was traded to the Yankees for "No No Nanette" cash.
# 405   Got chunky marmalade today of a greatful customer for my service over the past 2 yrs #PostieTweet #ServiceMatters http://t.co/pSEnGvyxrw
# 408   RT @lowcountry_luv: Attack animals, last house on the left by the lake, and she got colored eyes...we should have known.! Lol
# 411   RT @foodbibIe: Oreo Cheesecake http://t.co/yW299XjzB2
# 420   @boxingscene @RPopBox @BronzeBomber @boxing this Charlie Z really does need mental help check this out http://t.co/CkBS6WcZu1
# 425   @teapot Great GIF. Got a source URL for @gifs?
# 435   Nothing good on TV and the @Yankees are eating their balls 3 innings in. Great.
# 449   That was trash. I'm just gonna put my phone down. Goodnight
# 456   RT @anilkohli54: @mediacrooks so the ball did roll down the slope &amp; found a natural spot @madhutrehan defending brother &amp; the scumbag @sard&#8230;
# 484   RT @Yankees: Time to bounce in the Bronx. #LetsGoYankees #Walkoff http://t.co/W5ATfRsLKK
# 488   @AJ0427 Just watched the Llewyn Davis doc. Warm fuzzies abound &#9786;&#65039;
# 510   Frozen peas and \nibuprofen. My new best friends # cripple
# 531   Yep, sources confirmed it. That Iggy concert last night was trash
# 542   RT @AwwAdorable: I want a pet monkey &#128553;&#128525; http://t.co/8wy8gDJIEJ
# 544   "@ayyee_ceee_: One mans trash &#128686; is another mans treasure &#127942;"
# 551   I would describe @whatupag's work as blaxican.
# 552   I sho do miss my Uncle Tom
# 558   #NowPlaying : BT feat. Tori Amos - Blue Skies (radio edit) on #1069TheArrow - http://t.co/R5wuXA9jB6
# 577   What's a trash party ?
# 581   RT @walshnyc: Which World Cup Teams Are Jihadis Rooting For? http://t.co/ecU754zHKk @versharma @vocativ http://t.co/8z0B7ocMqP
# 584   I wanna try pot brownies.
# 592   @1Corinthians126 #Jesus Genesis 2:19 Out of the ground the LORD God formed every beast of the field and every #bird of the sky #Initiating
# 595   &#8220;@TWOLVEGIRL: I find myself wanting to google "the yellow king" #TrueDetective&#8221; No kidding! What is going on?
# 599   &#8220;@wwwobert_: B Oreo a stunt&#8221;come thru &#128293;&#128293;&#128293;
# 600   I hope the Yankees get Soriano, shoulda never gave him away for Alex Rodriguez
# 609   cousin: why is there a bird on your screen\nme: it's twitter\ncousin: i poke you\nme: that's facebook
# 617   &#8220;@HeyKeifer: Oreos are basically dirt circles with cream.&#8221; True.
# 618   pancakes trash
# 619   RT @RealTimeWWII: 6000 people/day now being deported from Warsaw ghetto, packed into cattle cars for rail trip to Treblinka death camp. htt&#8230;
# 629   @hardball @Milbank Chris stop your angry bird spitting n Dana go hail ur racial tendicies, u didn't infor, carter rt n u never talk abt him
# 638   "Your teeth are like the stars." "Aww thanks!" "Yeah... yellow and far away from each other."
# 654   &#8220;@CommonBlackGirI: here&#8217;s to all the kids who have never found their name on anything in a souvenir store&#8221; thanks mom for the ghetto name.
# 669   Can someone please explain to me, Why are the birds so angry &amp; destroying pigs' homes?
# 674   RT @A_single_bear: I accidentally ate a few fireflies last night while chewing some leaves I found. The shameful yellow glow of my mouth wa&#8230;
# 685   POLLOS A L'AST\n\nDos pollos estaban dando vueltas en una poller&#237;a mientras los estaban cocinando a l'ast, cuando... http://t.co/fXeEAJmyfZ
# 694   Early bird gets the worm.... #GoGetIt
# 696   @kayt27 poor coon.......snow stopped here,now if the wind would it might be nice out,well for winter
# 702   RT @cpabry: Curious George, the curious little monkey or deranged serial cat killer? The story the man with the yellow hat doesn't want you&#8230;
# 709   @ChrisTrondsen @IM5band #askim5 would you rather drink squirrel pee or Johnny Depp's wig in Charlie and the Chocolate Factory?
# 710   RT @BasedPaco: The NFL is very equal this season everybody showed glimpses of being trash
# 711   &#8220;@wizkhalifa: On the east coast there's colored hair everywhere. \n\nThis must be the sweetest wave ever.&#8221; @LayaFace
# 713   @Yankees isn't that kind of saying the #Braves won't make it to the World Series? LOL
# 717   So am I the only cracker up playing his guitar (thank you @Tampa_Rick ) on this Saturday night?
# 727   I was flying down the slope and just rammed into this small Asian boy, kid got up like a champ and walked it off
# 736   &#9733; BEST ASIAN MASSAGE ON THE park slope --TOP RATED SPA &#9733; 718-622-0221 - 24 http://t.co/Nkvy9nwyzj
# 748   After seeing Kansas play Duke a couple weeks ago, I could tell you I'm surprised that Charlie Weis has been let go...but I'm not.
# 750   @paolo Like...Charlie Chan-style? (Never saw that, either.) Hmm...makes me think of the "Cockneys" in the Killzone series.
# 752   Special thanks to Tina, Charlie and staff at Waverly Hills... thanks to everyone that dedicated time to make the... http://bit.ly/aKyqk2
# 766   RT @KarenRFM: No-TV-During-the-Week #parenting rule has thrown quite a monkey wrench into #RooseveltsPBS viewing schedule. #DVRtime @wcve #&#8230;
# 792   Magellan? You suck at trash talk. @physguy2 @submix8c
# 803   who's downie like a brownie 4 brunch? Need mimosas
# 804   Nothing more yokel MSU fan than to constantly reassess Izzo *aka our only consistent winner since D. Daugherty or Biggie flipping Munn*
# 823   @shrekkalove \nYou speak colored too?\nI thinks I be in love
# 826   Legion of jig &#128557;&#128557;&#128557;
# 830   Un pollito cruzaba la frontera, un zorro se tropieza con el pollo, el zorro le dice, im sorry el pollo le dice im... http://t.co/oXcOYauJi1
# 852   Fairy tale world lmao
# 864   third party keyboards on iOS 8 trash
# 866   Gotta keep the sox down while they're down! #RedSox #Yankees #mlb
# 878   &#8220;@iCARLEYBBY: &#8220;@DJZeeti: twitpic a selfie with light colored eyes&#8221; http://t.co/BSOYlL83Iz&#8221;&#128525;
# 884   @ilovemytroops @SenatorTimScott I see. So you feel betrayed, your racism comes out. Shocked you didn't call him Uncle Tom you bitter loser
# 909   I've pretty much eaten an entire box of my nephew's cheese nips. I only feel bad a little.
# 916   @McLaffyTaffy Reason #2 I didn't order a shirt: Taffy will know where I live and he would probably find me and stab me.
# 926   RT @23Vnds: Check out the homie @renz360 for that sole sauce! That stuff does miracles!!! @renz360 @renz360&#8230; http://t.co/EecEzJRx6C
# 927   RT @Bidenshairplugs: I can't believe the cops shot this fine young man. There goes the cure for cancer...\n\n#FergusonOctober http://t.co/Leb&#8230;
# 933   @DannyMndz93 @Titan21Mtzzz he's still a pogue though
# 947   Charlie Baltimore look good for 45 &#128563;
# 949   @mtmcly he will need monkey bars on his tricycle
# 965   #Yankees Pineda needed that 6'7. Great play!
# 967   Currently being hit with the jig. Word.
# 970   RT @Yankees: You may cry after watching the Derek Jeter @Gatorade ad: http://t.co/hMO9Bxol0x http://t.co/0xdlxToci8
# 973   #WorldSeriesGame3 Hunter Pence is so annoying he should be a Red Sox player. Shave fool and take your Vyvanse&#9918;&#65039;&#9918;&#65039;&#128074;&#128074;#Yankees 2015!!
# 975   I still can't understand why we don't dump our trash in the ocean. it's pretty big and it'd surely be cheaper than launching it into space.
# 983   @JuMosq @zachkruse2 Yep. *sobs*\n\nI got my hopes up when a couple of the national guys (including that Kiper/McShay mock) had him slipping.
# 984   &#8220;@HumbleTeej: @elisabethepps where am I on this rating scale???&#8221; Depends. You still wearing them colored contacts or naw?
# 988   if ice jj fish gets all these looks , who really trash me or him
# 1000  The Walking Dead is trash people...\n\nThat is all. &#128514;
# 1003  RT @DogeTheDog: Wow\n Such banana\n So potassium \n Much yellow http://t.co/xINHDwyTqS
# 1004  if ur girl watch Snapped in front of u she trying to spook u!!!
# 1009  @oliver_______ if you're making 300 clams for betting 5, i hope you do it for a living
# 1022  @_spenceyy @5SOS not scanger
# 1043  RT @Yankees: Congrats to Derek Jeter, who will start at shortstop in his 14th and final All-Star Game! #FarewellCaptain http://t.co/5nhtJOx&#8230;
# 1045  RT @LOHANTHONY: i'm so hungry if someone would send me a flying parachute with brownies attached to it like they do in the hunger games tha&#8230;
# 1047  RT @bakedbeansbro: Throw me in trash http://t.co/GvGMJJ6vYi
# 1071  &#8220;@anallanusa32: 83 you're really cool you're good at basketball. And your a zebra &#127936;&#128060;&#8221; is this @WillBall4Life?
# 1083  RT @espn: Hot off the press, here&#8217;s Todd McShay&#8217;s first post-Combine NFL mock draft, including a new No. 1. http://t.co/su5ixWrthq
# 1086  #Yankees I ain't complaining about the Royals win or lose game7. They showed heart. AL ride or die! No flex zone. They earned it!
# 1090  I see ya big Boi in the Oreo V's
# 1096  @Stephicans mhmm tweet bird &#128037;
# 1101  Early bird catches the worm &#128074;
# 1120  @YungCofGOA @12YearsAHaitian need to start mcbob because Williams only shoot let him play with bird
# 1125  @urbasicyabish nigor??
# 1146  :) "@PeterDavidsonII: At some point, we need to discuss how delicious the vegan brownie from @busboysandpoets on u St. tastes!"
# 1162  @Dietrich1892 I'll show up and chug a beer or 8
# 1168  last thought before bed: in '92 we had a "mock election" in 3rd grade and i voted for Perot. maybe i related to his really big ears, idk.
# 1169  Thw White Iron Band plays this weekend in Fargo,ND at the Aquarium(21+) ,Friday(10-29-10) with Charlie Parr. The next night,Saturday...
# 1180  &#8220;@WORSTRAPLYRlCS: http://t.co/hE19TIfqFX&#8221;\n\nHow is this trash...
# 1191  @Anotherpotheadd lucky monkey
# 1220  Thank you Charlie, Happy Thursday @Charlie4927 @StacyDmomof5 @PattiSM74 @Kacado @cantUCIMblonde @RevkahJC
# 1228  This music is trash
# 1234  RT @kendramarie91: &#8220;@vngelinaa_: Tornado sirens.... Atleast I'll be dying with you guys @Xo_t33 @a_krizanovic @kendramarie91 &#128557;&#8221; and this ho&#8230;
# 1240  Almost half of North American bird species threatened by climate change http://t.co/dWSYB5BodA http://t.co/F0PVuLNf4c #Climate #Environment
# 1241  @MinuteManX1776 @TheyKnowNotWhat &lt;&lt; closet muzzie @MayberryJustin @AllForCountry @LilMissPrepper @ritzy_jewels @glinsan1
# 1243  @HalleyBrenks3 interesting #hick
# 1253  Wow. No yellow yet? = Pagenaud and Marco screwed. Maybe no yellow coming
# 1257  @gregorious13 I don't understand it, there's trash cans/dumpsters everywhere and if there's not, just wait till you go somewhere with one.
# 1265  RT @LuvKittensDaily: Oreo being adorable http://t.co/5ZMZVT0sUl
# 1272  RT @renz360: Got 5 20% off slots for sole sauce for the early birds today \n\nUse &#8220;SAVE20&#8221; at checkout \n \nhttp://t.co/x5bq5vzpPK
# 1275  Jindal seemed to be having an out-of-body experience enhanced by special brownies\nhttp://t.co/W0cyEcqKLo\nBj Up and At 'Em\n#stribpol #mngop
# 1277  @CapitolEVAN That's where I saw the leprechaun. He told me to burn things.
# 1281  Leave it up to me it would've been in the trash.... All of it.
# 1288  Finally got an updated pic with angel wing colored http://t.co/nWN9qRt5Xd
# 1295  RT @PlMPCESS: A silent protest in Philadelphia, performance artists protest the murder of Mike Brown while passerby's mock it. http://t.co/&#8230;
# 1301  5 bags of chips, 3 Rice Krispies, 3 seeds, 3 gummies, a pop tart, some crackers, 3 powerades, and a water yuhhh I'm good lol
# 1308  @cxslug I never did those games, but I was obsessed with Angry birds. Which is why it took me so long to do CCS. I was scared. Lol
# 1317  @britty_jurgens a music suggestion is "lil spook"
# 1319  Looking forward to #NCAA and #NBA basketball &#127936; in the states soon #iubb #hoosiers #pacers #PacerNation and of course breadsticks.
# 1325  Sitting on the deck, enjoying a #StoneIPA, watching/smelling the neighbors burn trash. #Missouri http://t.co/m9wYnrLtWz
# 1337  @ShojoAIE a bright neon yellow gauntlet
# 1342  RT @ProBirdRights: A marry between a man and woman people sloppery slop;then what is prevent a bird from marriage my sandwich??? I'm in lo&#8230;
# 1349  @mark_mac18 @sheppast @rianscalia groves is trash IMO
# 1351  @Lvl_7_Eevee @UnicornCowboy @hisorraya I just wanted brownies man
# 1366  Absolutely absurd that they even had to think about that call. #joke #zebras
# 1402  Swap meet bound #beaner
# 1406  &#8220;@MannyBDlopez: When you open your starburst candy and get 2 yellows http://t.co/F0dDbfEzB6&#8221; lmao bruh
# 1416  RT @BirdGang316: If you a bird throw it up #birdgang #EaglesNation
# 1428  This mint brownies recipe is made with almond flour, coconut palm sugar, coconut oil, and coconut mi http://t.co/XZZfDoLZDn
# 1430  Pic circulating on Jihadi feeds claiming an "ISIS flag" on top of Mount Arafa in the holiest day of pilgrimage http://t.co/46YfuflyZV
# 1434  RT @robertbevan77: It's like The Walking Dead, but with less Carl and more talking birds. ZOMBIE ATTACK!!! http://t.co/UOCsPyksSC http://t.&#8230;
# 1446  Do you really believe people evolved from apes? &#8212; Not really. I'm quiet convinced with the evolution of man but ... http://t.co/1RswGNpLtc
# 1465  RT @Dalilaaaaaa__: Flappy birds cheat codes http://t.co/nu6GjYQDJJ
# 1473  Apolonia Gardner of Imperial, CA misspells "phalarope" - a bird that resembles a sandpiper. The dreaded schwa! #spellingbee
# 1487  RT @SneakerPics23: Oreo 6's http://t.co/Jx9DD9oahY
# 1492  Yeah they do. RT @Yankees: Six complete here at The Stadium. #Yankees lead the Red Sox 3-1. #LetsGoYankees
# 1501  RT @Kiaranicole_x: @_JoAries @Kash_WingateLFC @chanchan_ox babes we buy brazilian and Peruvian not Bengali
# 1505  RT @JoeyG_145: Downloaded flappy bird 5 minutes ago... It's already deleted.
# 1512  @c_drew_ I'm guessing so. The players are talking trash.
# 1521  Holy monkey balls its warm today
# 1532  RT @FeinsandNYDN: Yankees acquire Chase Headley from the Padres for Yangervis Solarte and Rafael DePaula.
# 1538  RT @WashTimes: John Kerry caught appearing to mock Israel&#8217;s &#8216;pinpoint&#8217; operation in Gaza - http://t.co/3yqFR9LZsR #Israel #Gaza http://t.co&#8230;
# 1542  RT @NateKlempa: @ROOTSPORTSPIT must not realize how much #WVU games mean to all of us "hillbillies". The @Pirates play 162 games a year. Sh&#8230;
# 1547  @TheMayorMatt has to be #live version ! #pulledpork #clams #babyjesus #lilsmokey
# 1563  @Swamper60 "Happy Happy Helloween, Helloween whoa oh whoa ho" @helloweenorg http://t.co/Tw0jeExqTy
# 1573  Hold all your ghetto labeled and endorsed vodka brands, you can rum me silly any day. \n\n#ShiverMeTimbers
# 1575  This Billy Crystal tribute to Derek Jeter is crazy. I hate the Yankees, but man... Derek Jeter.... #RE2PECT
# 1578  RT @ProBirdRights: i see you again didn't election bird for government, america. that okay. i guess i just take this free cookie for everyo&#8230;
# 1580  @The_Gambit Ha. He ain't welcome in Washington State or Nashville. Serpas is straight trash.
# 1583  RT @TwitchyTeam: Low turnout reported, but Charlie Crist just filed and emergency motion to extend voting hours in Broward Co. http://t.co/&#8230;
# 1585  yaya ho.. cute avi tho RT @ViVaLa_Ari I had no idea she was sleep &#128553;
# 1598  Is dare any colored players in hockey?
# 1607  RT @49ers: Oregon State WR @brandincooks is a popular #49ers pick in recent mock drafts. \n\nDRAFT TRACKER: http://t.co/AEueKmhkQX http://t.c&#8230;
# 1616  @Alludra_AIE just remember to keep the skirt dark colored. It camouflages all that pan dimensional gore
# 1636  The beautiful Fairy Pools near Glenbrittle on the Isle of Skye, Scotland http://t.co/cyi6xSvn97
# 1653  My sister told me that I look like a bird. While my past told me that I look like an alien.
# 1654  RT @michaelpshipley: Martin Short On - CONAN - Oct 3, 2014\n\n"With your yellow skin and red hair you look like a #2 pencil."\n\nhttps://t.co/U&#8230;
# 1661  #hoosier fans, is cody zeller nominating for this years #NBA draft? #iubb
# 1675  @karmendanielle_ let the coons be great it's in the dream
# 1703  &#8220;@AbstractLife: @NigelDixon1 @SeanTHarrington Orton is trash idc&#8221; he ain't been playing. Trashlex Smith only sat out Kaep took his spot.
# 1711  U serious bro?? lol RT @CheezMoeJenkinz 2-3:10am early bird special
# 1719  Jihadi streams: British #ISIS fighter identified as Abu Abdurahman Al Britani killed in action. http://t.co/Ksowd8rRCk
# 1721  #mt #goauche #monkey #oldpainting #vinyl #jazz #lounge http://t.co/hueH4HCxx7
# 1730  @Ish_MallyMal @JayJuice22 all trash to me
# 1741  RT @bjs5555: ELECT Democratic Nominee Charlie Brown @Govcharliebrown for #Gov of #TN DEFEAT (R) Gov. Bill Haslam! @UniteBlueTN http://t.co/&#8230;
# 1744  Who needs an alarm when you have the worlds most annoying bird outside your window?!??
# 1750  @b0ssladyre just ate a wees brownie and is seeing random cats
# 1758  Why are people saying don't let guys treat you like a yellow starburst? That's my favorite.
# 1759  CAIR Publishes a Hit List for Jihadis http://t.co/hvVfXypmHm via @RealJTP If you are a red blooded #American you may be on the list..
# 1763  If you've ever been to drunk to fish, you might be a redneck
# 1767  being up at 5am cuz your cat meowed at a nocturnal bird is the ultimate #toughbreak
# 1768  oops: 'constitutionalists' #teabaggers in #mississippi forgot ratify a centerpiece of the constitution: 13th amendment banning slavery.
# 1772  Selling ex lax brownies in front of Meijer to pregnant women. #GoodDeed
# 1773  @mandaxll2963 yellow is even better
# 1774  Damn internal alarm clock. Woke up at 6:35am feeling chunky from my 3am Cheerios splurge. Guilt led me to the treadmill. #Gym #nosleep
# 1778  #tikiti - rough mock for the base of what will eventually be an ashtray @ Tiki Ti http://t.co/8zE8aqY0
# 1789  This one night I was tripping off brownies I put my running shoes on and I was still in pjs, it was 2am ! http://t.co/UwmBpCOMNE
# 1792  Grandma's Homemade Potato Soup - An old fashioned, simple, chunky potato soup like Grandma made, wit http://t.co/ZV8ZsmHNlm
# 1793  @WHAScameradan We might have more. Can't really be sure. But some weird little bird said that might be a possibility. Stay tuned. Maybe.
# 1798  RT @runofplay: I'm confused. Martins Indi just drew a yellow card, but I didn't see him steal a tank from the Brazilian army and open fire &#8230;
# 1802  That warm fuzzy feeling when you're able to give someone a helping hand. Talking about medical problems with others can really help.
# 1811  RT @HMSguy: Rahal's an idiot. Second time this year he's wrecked someone under yellow.
# 1813  @Liveitupjersey BWAHAAAA I just choked on an Oreo cookie!\nI'M figuring, this may have something to do with it! http://t.co/62S7BgMYPX
# 1817  Tommy trash
# 1819  i thought garbage men were supposed to bring trash to the dump but they wouldn't take me ha ha ha. self depreciation ftw.
# 1821  RT @TheRoot: Don Lemon gets called an Uncle Tom, doesn't like it: http://t.co/eV4xgI5Pgc http://t.co/i6Xs8HCnrb
# 1833  This waiting thing is for the birds...
# 1839  Don&#8217;t believe AP&#8217;s ho-hum tone: latest poll is great news for Republicans - Hot Air http://t.co/5HHrFlFP13
# 1845  .@AlyssSmithh @KeveeeD Yes indeed! Camels, ostriches and zebras! Sept. 5-7 http://t.co/X3Oapfm3e8 #VCCamelRaces
# 1848  cut up porkchop, canned pinto beans, a small can of carrots, can of corn, celery, a potato. cayenne powder + crushed red pepper
# 1855  Charlie is so adorable. http://t.co/TMpBYyjGFL
# 1858  RT @MarcACaputo: BREAKING: Charlie Crist files emergency motion for a mulligan.
# 1866  RT @Perspective_pic: Retweet if you see the bird. http://t.co/o7reXL0teu
# 1867  @luchadora41 so was slavery, prohibition and not letting women to vote... segregation jim crow laws.. etc etc i can do this all day lol
# 1889  @MahNameIsJared be my guest. I want to be a bird I think
# 1892  I'd be the best at owning a bird. I could teach them the funniest things to say.
# 1893  @Nashgrier purple monkey
# 1894  RT @briangaar: Old white people complaining about government tyranny is like the Yankees being upset that players make too much money
# 1907  RT @bitterarab: Now that Halloween is fast approaching please understand this. We are a culture, not a costume to mock and ridicule! http:/&#8230;
# 1923  Your A Good Gravedigger, Charlie Brown #SpookyBroadway @midnight
# 1942  the train station Harry's at is trash I've been to the same Eurostar too they refunded my whole trip to Paris bc train accident
# 1944  RT @ticiaverveer: Royal city of the Kushite kings at Meroe (Sudan),near River Nile.It was the seat of the rulers who occupied Egypt http://&#8230;
# 1947  @Notsosweetpea I like brownies &#128546;
# 1949  Looking back I liked colored better. Let's go back to that
# 1958  I'm such a retard sometimes.
# 1959  One mans trash is another mans treasure
# 1970  Early bird gets the worm right? Hopefully I get a job soon after today! http://t.co/lvgfVBqkdz
# 1978  @Pepper_Redbone @Yankees @Mets Oh yeah. And the annoying damn duck calls?? They outta be banned. Duck horns??
# 1979  RT @JStac825: There's coon classic (R. Kelly, Usher) and then there's classic (Stevie Wonder, Prince). Not that there's anything wrong with&#8230;
# 1984  RT @JohnnyFootbalI: Yeah Kaepernick might have biceps like a Greek God, but the dude looks like he was conceived by a Proboscis monkey http&#8230;
# 1992  Jihadis betting on public protests in Britain to force UK gov out of the anti-ISIS coalition http://t.co/5gJSmrfzWJ
# 2013  if u eat fried eggs and leave the yolk entirely yellow ur a disgrace and also nasty
# 2028  RT @missmollylo: Charlie wears women's clothing
# 2034  RT @Elisaa_Martinez: Happy birthday cotton picker lol @1NOnlyDirtyMike
# 2035  @Misters206 You look like a monkey
# 2044  It's almost Christmas, Charlie Brown...
# 2051  @JonJ_07 like their players really been talking trash about Bama.
# 2073  I want a slope job so I can get away from everything and be by myself for two weeks. I hate being around people unless they are my friends.
# 2094  it's so weird outside. it's like yellow.
# ...
# 1907  RT @bitterarab: Now that Halloween is fast approaching please understand this. We are a culture, not a costume to mock and ridicule! http:/&#8230;
# 1909  RT @AyMrCarter: Apologies trash.. What's understood ain't gotta be explained
# 1923  Your A Good Gravedigger, Charlie Brown #SpookyBroadway @midnight
# 1938  RT @CyFyre: @WesOrrJames love you too my nig #squad
# 1942  the train station Harry's at is trash I've been to the same Eurostar too they refunded my whole trip to Paris bc train accident
# 1943  RT @ShelleT1986: Great start the morning! My daughter danced herself into the coffee table and gave herself a nice shiner... Yea she's a wh&#8230;
# 1944  RT @ticiaverveer: Royal city of the Kushite kings at Meroe (Sudan),near River Nile.It was the seat of the rulers who occupied Egypt http://&#8230;
# 1947  @Notsosweetpea I like brownies &#128546;
# 1958  I'm such a retard sometimes.
# 1959  One mans trash is another mans treasure
# 1961  @ASourAppleTree Have heard hillbilly grousings that bugs much worse in the KV since MIC shut down.
# 1970  Early bird gets the worm right? Hopefully I get a job soon after today! http://t.co/lvgfVBqkdz
# 1978  @Pepper_Redbone @Yankees @Mets Oh yeah. And the annoying damn duck calls?? They outta be banned. Duck horns??
# 1979  RT @JStac825: There's coon classic (R. Kelly, Usher) and then there's classic (Stevie Wonder, Prince). Not that there's anything wrong with&#8230;
# 1984  RT @JohnnyFootbalI: Yeah Kaepernick might have biceps like a Greek God, but the dude looks like he was conceived by a Proboscis monkey http&#8230;
# 1992  Jihadis betting on public protests in Britain to force UK gov out of the anti-ISIS coalition http://t.co/5gJSmrfzWJ
# 2013  if u eat fried eggs and leave the yolk entirely yellow ur a disgrace and also nasty
# 2028  RT @missmollylo: Charlie wears women's clothing
# 2034  RT @Elisaa_Martinez: Happy birthday cotton picker lol @1NOnlyDirtyMike
# 2035  @Misters206 You look like a monkey
# 2044  It's almost Christmas, Charlie Brown...
# 2051  @JonJ_07 like their players really been talking trash about Bama.
# 2066  @Boobah_ they trash
# 2073  I want a slope job so I can get away from everything and be by myself for two weeks. I hate being around people unless they are my friends.
# 2087  The right for an English person to go about his business is more important than any suspicion of some rouge wog cop.
# 2094  it's so weird outside. it's like yellow.
# 2099  RT @LilyBean1313: And I thought I had a problem! #Oreos http://t.co/jfrBKzE1T5
# 2101  @KeiveeB yellow shirt hat turnt to da side
# 2111  wish I had a brownie or a dab to knock me out rn
# 2118  @littlelouie33 eh, take off hoser.
# 2121  @Auroramwj @marylmcaffry @BBAnimals It's a mutation. Genealogy is convoluted. Basically the zebra gene currieries are slaughtered=Extinction
# 2125  @caraabastow That's a cute and fuzzy one...hehehe ;)
# 2128  Whipped http://t.co/EFSVjPqrwq
# 2130  @mis_sarahd @basedpapi1017 tranny
# 2132  RT @chilltweetss: flappy bird is deep... hahaha http://t.co/EMuhmR3jzE
# 2143  Omer Asik so trash on the offensive side of the floor dude real life murky doo doo water
# 2146  #Yankees got beaten by a thug
# 2153  RT @RayHudson: Art thou the bird whom Man loves bestThe pious bird with t/ scarlet breast, Our Robin;that leaves these summer winds sobbing&#8230;
# 2158  Apparently im a honky. Pfft. Like that's a bad thing.
# 2162  @ashleyypat17 if im trash ur trash since we baes now
# 2169  @HBergHattie @snkscoyote I wonder if the progs didn't relegate young black men to the ghettos to keep them away from harry reid's friends...
# 2185  Bet they want a cookie, Bergbrain? You mean like you want a cracker? Kinda bitter here today aren'tcha? #stribpol mngop #mnleg
# 2186  A white lighter is bad luck, not yellow ur stupid
# 2187  RT @SunSentinel: The @SunSentinel Editorial Board endorses Charlie Crist for governor -- Better for Floridians http://t.co/t21z2YBZlQ http:&#8230;
# 2189  Other Jihadi news #ISIS executed #Kuwait preacher Redha Lari coz he was..&#8220;too extreme&#8221; &amp; hampered reconciliation with Nusra with his fatwas
# 2196  RT @Kevineffinskaff: My idea of a diet is eating regular Oreos instead of double stuft and takin off half the cookie (still dip it in 2% ...
# 2198  RT @MTVUK: #Directioners, 1D's @zaynmalik &amp; @Louis_Tomlinson monkey around on set of #StealMyGirl video: http://t.co/sOEbNlR8Re http://t.co&#8230;
# 2203  Is there a looser #college town than #BTown ??? If yes id like to visit #IU #hoosiers
# 2210  RT @Yankees: #Yankees win! Final score: 7-4.
# 2220  Thanks Charlie, have a great evening @Charlie4927 @StacyDmomof5 @RevkahJC @cantUCIMblonde @Kacado @PattiSM74
# 2221  RT @Maxicat: Charlie Rangel Re-Writes History: On GOP &#8220;They Think They Won The Civil War&#8221; http://t.co/moCeUBRUTf
# 2246  RT @jrsalzman: Buzzfeed males who live in the city and buy meat under plastic, mock girls who use guns and go hunting. Who is more manly?
# 2247  Lmaoooooo @ Supreme being trash. Guess Bape is trash to huh?
# 2252  I hate Hashtag activism. No lie. I think 95% of it is trash.
# 2257  Tomorrow's agenda: bake brownies &amp; visit a couple open house.
# 2263  "Is that an albino Mexican?"\n"No dad, he's Asian."
# 2268  @HeatherEliseP and plus, it's trash talk. You should know that especially with ole miss.
# 2277  Perhaps I'm not a "diehard" Yankee fan, but there's no more point in watching this debacle #Yankees #Tigers #MLB So what else is on? LOL
# 2279  The Bucs has 2 great uniforms and ruined them both for that trash smh
# 2282  RT @USAgov: Our national bird - the American bald eagle - is an endangered species success story. http://t.co/OJscNNMYEm
# 2284  So my light was off &amp; door was closed , mom walks in turn lights on . Tells me to take trash out in the morning . then walked out.. Light on
# 2285  Game 126 Preview: Houston #Astros at New York #Yankees http://t.co/sVg7dIIcZG
# 2290  Best rider? That goes to a blaxican.
# 2291  jacob u look like a monkey in dis http://t.co/rkaqn0GRQe
# 2295  Wicked Oreo
# 2297  Be fearful of the wrath of God in a country where many mock Christianity, embrace perversion, abortion, and bows to PC/multiculturalism.
# 2307  Shut up birds it's bed time.
# 2310  @erinscafe Bu I do. I do hate the playa. And the Yankees. If I hate the Yankees for their payroll I have to hate the Dodgers.
# 2312  HOW &#8220;@darrenrovell: Deep Fried Sweet Tea on a graham cracker crust at State Fair of Texas (via @gravweldon) http://t.co/KVzhlmCsls&#8221;
# 2316  RT @cwissi: beanies for life &#9697;&#776;&#8413; http://t.co/iywPwmPGTu
# 2320  RT @lnsaneTweets: when other girls wear beanies they look cute &amp; stylish but when i wear them i look like a member of a drug cartel who sel&#8230;
# 2330  RT @SenorSteez: This whole week was trash
# 2337  RT @Fact: Fake friends are no different than shadows, they stick around during your brightest moments, but disappear during your darkest ho&#8230;
# 2344  i was such a teacher's pet in elementary school. like i brought them cookies and brownies and gave them hugs. im ashamed
# 2347  @EASPORTSFIFA next update, would be AMAZIN if two celebrations were added. 1: Shirt off ( we'll take the yellow) and 2: The RKO
# 2351  RT @PlMPCESS: In the fashion world "urban" definitely means "stolen from black people" it's ghetto on us, and urban on them haha http://t.c&#8230;
# 2370  RT @TheRisingStar23: Shy Glizzy Decent Af
# 2376  RT @ESPNNFL: For the 1st time in the Tom Brady era, the Patriots are in sole possession of last place in the AFC East http://t.co/zMkwGNzOCT
# 2383  @AdamSchein @TheMayorMatt I may have just cried a tad #illmissu shiner
# 2388  Oops, I just had a Freudian slit.
# 2391  @InedibleFood Quickscoping trash. TAKE OF THE TONY HAWK SETUP AND PLAY NORMALLY. THAT'S NOT WHAT SNIPERS ARE FOR!
# 2404  RT @chelseaxlaser: I really need to take my rose colored glasses off though. I gotta stop thinking everybody does shit with good intentions&#8230;
# 2405  @WakeUpPeeps1 Read w/o slant your orig statement said 'everything' we have...that is the only extreme comment made
# 2407  Finished Yankeeography and still hate the Arizona D'backs for winning in 2001, Yankees shoulda had that
# 2427  Western Jihadi fanboys use of language: peppering sentences with Arabic words to sound knowledgeable - #Comical http://t.co/G2rca1XGh7
# 2431  @LoLDyrus It's retarded. Ignore the harlem shake fad and hope it goes away soon.
# 2432  RT @SimpsonsQOTD: &#8220;That's a very nice jig, Kearney. Now isn't dancing much more fun than bullying?" http://t.co/dk7rcqM1FS
# 2437  Good morning Twitter. Make today a positive one. If you can't do that, beat up as many meanie-faces as possible. Also, I hate flappy bird.
# 2446  The #teabagger #freemarket really doing wonders in #Bangladesh these last couple of days. #tcot #p2 #teaparty #randpaul
# 2467  Lmao RT @iPOSTBADTWEETS: Lowkey Peyton Manning trash

# %%
test_bnt_hb_combined_missed_hate = test_bnt_hb_combined_missed.loc[test_bnt_hb_combined_missed['class']==2][['tweet']]

# %%
#test_bnt_hb_combined_missed.to_csv("test_bnt_hb_combined_missed.csv", sep='\t')

# %%
#test_bnt_hb_combined_correct.to_csv("test_bnt_hb_combined_correct.csv", sep='\t')

# %%
#test_hand_built_missed.to_csv("test_hand_built_missed.csv", sep='\t')

# %%
#test_hand_built_correct.to_csv("test_hand_built_correct.csv", sep='\t')

# %% [markdown]
# ## Compare with baseline

# %%
test_baseline_correct = pd.read_csv('test_baseline_correct.csv', sep='\t')[['tweet','class','prediction']]
test_baseline_correct_hate = test_baseline_correct[test_baseline_correct['class']==2][['tweet']]
test_baseline_correct_hate
# Out:
#                                                                                                                                                                              tweet
# 13    RT @DamnFoodPorn: Oreo Cookie Pancakes #FoodPorn http://t.co/q6EvCvM3sO
# 28    Fairy Tale Hat - free crochet pattern for child and adult at http://t.co/0lRaBLMHB2 http://t.co/99zVbmYVe9
# 45    RT @daraobriain: Tommy Voeckler keeps the yellow, Andy Schleck does the break of the tour, and Contador is broken. Incredible day for #tdf
# 50    Watching #Steelers colts getting blinded by the Steelers uniys look like bunch of bumblebees
# 52    RT @netflix: Here's your first look at Charlie Cox as Matt Murdock in #Marvel's @Daredevil on #Netflix #NYCC http://t.co/SIYuCgok8J
# 63    Ravioli stuffed wit lobster nd a nice stuffed clam #eating betterthanamobster http://t.co/PzdoESaR
# 67    I want a four loco right now so I can chug it and go straight to sleep.
# 81    #Yankees Damn. Well Joe that move to the bullpen really helped.
# 84    Next time you leave magic trash in my jacket try not to have your initials written on them. @whatupag http://t.co/tFV1cZtr
# 100   Yankees getting killed
# 105   This picture on Weibo made China's censors add "big yellow duck" to its list of banned terms &#8594; http://t.co/87NSk91rJR http://t.co/j3aAKxwIfe
# 108   Islamic Jihadis run away to Pakistan @PureMonotheist @BemetOr8 #UniteBlue
# 112   RT @Shalewis09: Larry Elder is an Uncle Tom. I cannot believe how he is degrading a child.
# 134   RT @koolestbreeze: Thanks Charlie!! http://t.co/iw06cCEkND
# 139   @rochaaxx yellow
# 140   RT @HoodJesusYo: Last name, Sinner\nFirst name, Imma\nLike ur pancakes in tha mornin, \nHe got u covered like Aunt Jemima
# 143   RT @chilltweetss: when I make the paper ball into the trash can &#128168; http://t.co/Xnx2XEGACm
# 149   Jay Z - Takeover &amp; U Don't Know LIVE @ Home &amp; Home Concert Yankee Stadium: http://t.co/4EuK80uLiS via @YouTube
# 151   Noap. Not taking them. RT @TiffNCompany: Maca root pills making my vagina do the wop
# 153   @_BradleyC skate 2 trash :(:( skate 3 had goat DLC
# 165   @JonnieSantana He's definitely trash. But if Bill Cohwer or Stanford 's head coach want the job I'd hire them. With a new gm of course
# 173   This Charlie Murder game is pretty dope #Xbla
# 178   @Buckm00se @LEXXX_RUGER @ivanrabago_ the kikes want to charge you &#128175; dollaz for the complete version http://t.co/ZJDLwiAjEo
# 181   @louiev_ lol just getting this..early bird catches the worm!
# 188   bae won his game &#128525; #redskins
# 196   Oriental rugs cause I'm flyer than a dove.
# 197   "How about we draft all those gung-ho folks and send them to Afghanistan or other war zones so they can show their... http://t.co/sR1zceHx
# 198   @washingtonpost The people who work at those companies tend to be trash.
# 203   RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;
# 211   RT @NickSwagyPYoung: Happy Halloween from Rick James (aka Swaggy) and Charlie Murphy ( @bigmeat2000 ) haha darkness everybody http://t.co/y&#8230;
# 212   RT @MaryWCVB: Still waiting for Charlie Baker to take the stage in Swampscott. #wcvb http://t.co/lYb3Thm199
# 237   Tuna is good the rest trash RT @AyeoFool: Cans of spam RT @MsBTxo: Most struggle food HAS TO BE any meat In a can, tuna included
# 240   RT @CHlLDHOODRUINER: she paid $5 to hold the monkey and look what he did &#128514;&#128557;&#128553; this monkey real af http://t.co/NgeCuWehHb
# 245   We over here struggling with college and work and ice jj fish making money for being trash lol. What has this world come to.
# 251   First jig of the night
# 253   RT @sportswithjohn: Dani Alves uses his new gray hair to talk himself out of a yellow card, telling the referee, "I am but a humble senior &#8230;
# 255   "@UberFacts: 15 sad TV character deaths we're still bitter over... http://t.co/uLclFUF8nC http://t.co/1RXYQOOsM0"ned stark was the man
# 256   MT: "@DocKozlowski: Ted Cruz "We are proud wacko birds". #StandWithCruz #KeepCruzing" is that a pun?
# 265   RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0
# 268   can my cat not kill birds and make a huge mes of feathers
# 270   No more speculation. No more mock drafts. It's finally Draft Day. #BortlesKombat #StormWarning #BuiltByUCF #ChargeOn
# 271   yea so about @N_tel 's new friend.. all my friends kno they're only allowed one cute darkie friend n that's me! lol
# 274   @OldManRo you should check it out... it aint animated and has Charlie Murphy in it
# 291   @wodaeeex3 it didnt open das y i asked cus i thought yu ate wat i had Pork chops yellow rice n beans
# 298   Early worm gets the bird #Bslfe #GoodMorning http://t.co/dfE8MF2Q28
# 306   I ate a monkey. #AndNowIHaveEbola
# 308   Charlie Rangel: Some Republicans 'Believe That Slavery Isn't Over' | Truth Revolt: http://t.co/NpbdPk0Cqz \nBam, Race Card Vote Democrats out
# 316   RT @RudeBoi_Drew: @PAPER_CHAYSIN condom were invent for that sole purpose
# 324   RT @MindOnSuccess_: My mother be on some trash man &#128514; I ask her EVERYDAY, you need/ want some money? She say "Naw I'm good!" But come payday&#8230;
# 325   RT @Macbeth870: #bowebergdahl There hasn't been a trade this lopsided since Babe Ruth was traded to the Yankees for "No No Nanette" cash.
# 327   Got chunky marmalade today of a greatful customer for my service over the past 2 yrs #PostieTweet #ServiceMatters http://t.co/pSEnGvyxrw
# 330   RT @lowcountry_luv: Attack animals, last house on the left by the lake, and she got colored eyes...we should have known.! Lol
# 333   RT @foodbibIe: Oreo Cheesecake http://t.co/yW299XjzB2
# 341   @boxingscene @RPopBox @BronzeBomber @boxing this Charlie Z really does need mental help check this out http://t.co/CkBS6WcZu1
# 345   @teapot Great GIF. Got a source URL for @gifs?
# 371   RT @anilkohli54: @mediacrooks so the ball did roll down the slope &amp; found a natural spot @madhutrehan defending brother &amp; the scumbag @sard&#8230;
# 395   RT @Yankees: Time to bounce in the Bronx. #LetsGoYankees #Walkoff http://t.co/W5ATfRsLKK
# 398   @AJ0427 Just watched the Llewyn Davis doc. Warm fuzzies abound &#9786;&#65039;
# 416   Frozen peas and \nibuprofen. My new best friends # cripple
# 435   Yep, sources confirmed it. That Iggy concert last night was trash
# 444   RT @AwwAdorable: I want a pet monkey &#128553;&#128525; http://t.co/8wy8gDJIEJ
# 446   "@ayyee_ceee_: One mans trash &#128686; is another mans treasure &#127942;"
# 449   I would describe @whatupag's work as blaxican.
# 450   I sho do miss my Uncle Tom
# 455   #NowPlaying : BT feat. Tori Amos - Blue Skies (radio edit) on #1069TheArrow - http://t.co/R5wuXA9jB6
# 471   What's a trash party ?
# 475   RT @walshnyc: Which World Cup Teams Are Jihadis Rooting For? http://t.co/ecU754zHKk @versharma @vocativ http://t.co/8z0B7ocMqP
# 478   I wanna try pot brownies.
# 485   @1Corinthians126 #Jesus Genesis 2:19 Out of the ground the LORD God formed every beast of the field and every #bird of the sky #Initiating
# 488   &#8220;@TWOLVEGIRL: I find myself wanting to google "the yellow king" #TrueDetective&#8221; No kidding! What is going on?
# 490   &#8220;@wwwobert_: B Oreo a stunt&#8221;come thru &#128293;&#128293;&#128293;
# 491   I hope the Yankees get Soriano, shoulda never gave him away for Alex Rodriguez
# 506   pancakes trash
# 507   RT @RealTimeWWII: 6000 people/day now being deported from Warsaw ghetto, packed into cattle cars for rail trip to Treblinka death camp. htt&#8230;
# 516   @hardball @Milbank Chris stop your angry bird spitting n Dana go hail ur racial tendicies, u didn't infor, carter rt n u never talk abt him
# 547   Can someone please explain to me, Why are the birds so angry &amp; destroying pigs' homes?
# 552   RT @A_single_bear: I accidentally ate a few fireflies last night while chewing some leaves I found. The shameful yellow glow of my mouth wa&#8230;
# 567   RT @AmandaMarcotte: &#8220;Not all men interrupt women to quibble over irrelevant issues for the sole purpose of derailing a conversation,&#8221; he sa&#8230;
# 569   Early bird gets the worm.... #GoGetIt
# 571   @kayt27 poor coon.......snow stopped here,now if the wind would it might be nice out,well for winter
# 581   @ChrisTrondsen @IM5band #askim5 would you rather drink squirrel pee or Johnny Depp's wig in Charlie and the Chocolate Factory?
# 582   RT @BasedPaco: The NFL is very equal this season everybody showed glimpses of being trash
# 583   &#8220;@wizkhalifa: On the east coast there's colored hair everywhere. \n\nThis must be the sweetest wave ever.&#8221; @LayaFace
# 585   @Yankees isn't that kind of saying the #Braves won't make it to the World Series? LOL
# 588   So am I the only cracker up playing his guitar (thank you @Tampa_Rick ) on this Saturday night?
# 596   I was flying down the slope and just rammed into this small Asian boy, kid got up like a champ and walked it off
# 603   &#9733; BEST ASIAN MASSAGE ON THE park slope --TOP RATED SPA &#9733; 718-622-0221 - 24 http://t.co/Nkvy9nwyzj
# 615   After seeing Kansas play Duke a couple weeks ago, I could tell you I'm surprised that Charlie Weis has been let go...but I'm not.
# 617   @paolo Like...Charlie Chan-style? (Never saw that, either.) Hmm...makes me think of the "Cockneys" in the Killzone series.
# 619   Special thanks to Tina, Charlie and staff at Waverly Hills... thanks to everyone that dedicated time to make the... http://bit.ly/aKyqk2
# 631   RT @KarenRFM: No-TV-During-the-Week #parenting rule has thrown quite a monkey wrench into #RooseveltsPBS viewing schedule. #DVRtime @wcve #&#8230;
# 645   @SusanneWhite they're so goooood. I just want like a savoury salty cheesy cracker
# 651   RT @kristinhersh: my son, Wyatt: "do rednecks have mullets to keep from getting red necks?"
# 655   Magellan? You suck at trash talk. @physguy2 @submix8c
# 657   Whipped out some french in front of some babes at the post office. #winning
# 661   You know I'm not big on the NFL, but I'm so sick of hearing all of this "Black and yellow" shit. LOL @ bandwagon fans and hell, GO PACKERS!
# 666   who's downie like a brownie 4 brunch? Need mimosas
# 667   Nothing more yokel MSU fan than to constantly reassess Izzo *aka our only consistent winner since D. Daugherty or Biggie flipping Munn*
# 679   RT @Kick_Man: Giants- Pitiful .. Jets-Pitiful .. Mets- Pitiful .. Yankees-Pitiful .. Nets- Pitiful .. Knicks-Pitiful ... Ny sports- Pitiful
# 682   @shrekkalove \nYou speak colored too?\nI thinks I be in love
# 685   Legion of jig &#128557;&#128557;&#128557;
# 689   Un pollito cruzaba la frontera, un zorro se tropieza con el pollo, el zorro le dice, im sorry el pollo le dice im... http://t.co/oXcOYauJi1
# 706   Fairy tale world lmao
# 715   third party keyboards on iOS 8 trash
# 717   Gotta keep the sox down while they're down! #RedSox #Yankees #mlb
# 725   &#8220;@iCARLEYBBY: &#8220;@DJZeeti: twitpic a selfie with light colored eyes&#8221; http://t.co/BSOYlL83Iz&#8221;&#128525;
# 729   @ilovemytroops @SenatorTimScott I see. So you feel betrayed, your racism comes out. Shocked you didn't call him Uncle Tom you bitter loser
# 749   &#8220;@wassssupsarah: Car hopping is a different world these ghetto guys tried asking for my number LOL&#8221; did they have to be ghetto Tho ?
# 752   I've pretty much eaten an entire box of my nephew's cheese nips. I only feel bad a little.
# 756   @McLaffyTaffy Reason #2 I didn't order a shirt: Taffy will know where I live and he would probably find me and stab me.
# 764   RT @23Vnds: Check out the homie @renz360 for that sole sauce! That stuff does miracles!!! @renz360 @renz360&#8230; http://t.co/EecEzJRx6C
# 765   RT @Bidenshairplugs: I can't believe the cops shot this fine young man. There goes the cure for cancer...\n\n#FergusonOctober http://t.co/Leb&#8230;
# 781   Charlie Baltimore look good for 45 &#128563;
# 783   @mtmcly he will need monkey bars on his tricycle
# 793   #Yankees Pineda needed that 6'7. Great play!
# 795   Currently being hit with the jig. Word.
# 797   RT @Yankees: You may cry after watching the Derek Jeter @Gatorade ad: http://t.co/hMO9Bxol0x http://t.co/0xdlxToci8
# 799   #WorldSeriesGame3 Hunter Pence is so annoying he should be a Red Sox player. Shave fool and take your Vyvanse&#9918;&#65039;&#9918;&#65039;&#128074;&#128074;#Yankees 2015!!
# 800   I still can't understand why we don't dump our trash in the ocean. it's pretty big and it'd surely be cheaper than launching it into space.
# 807   @JuMosq @zachkruse2 Yep. *sobs*\n\nI got my hopes up when a couple of the national guys (including that Kiper/McShay mock) had him slipping.
# 808   &#8220;@HumbleTeej: @elisabethepps where am I on this rating scale???&#8221; Depends. You still wearing them colored contacts or naw?
# 811   if ice jj fish gets all these looks , who really trash me or him
# 822   The Walking Dead is trash people...\n\nThat is all. &#128514;
# 824   RT @DogeTheDog: Wow\n Such banana\n So potassium \n Much yellow http://t.co/xINHDwyTqS
# 828   Got my vans on.. My pockets chunky
# 829   @oliver_______ if you're making 300 clams for betting 5, i hope you do it for a living
# 842   @_spenceyy @5SOS not scanger
# 860   RT @Yankees: Congrats to Derek Jeter, who will start at shortstop in his 14th and final All-Star Game! #FarewellCaptain http://t.co/5nhtJOx&#8230;
# 862   RT @LOHANTHONY: i'm so hungry if someone would send me a flying parachute with brownies attached to it like they do in the hunger games tha&#8230;
# 864   RT @bakedbeansbro: Throw me in trash http://t.co/GvGMJJ6vYi
# 872   If only I dated a girl that lived off Mack Road I could just get the holy trinity of Sacramento ghettos on a daily basis
# 885   &#8220;@anallanusa32: 83 you're really cool you're good at basketball. And your a zebra &#127936;&#128060;&#8221; is this @WillBall4Life?
# 896   RT @espn: Hot off the press, here&#8217;s Todd McShay&#8217;s first post-Combine NFL mock draft, including a new No. 1. http://t.co/su5ixWrthq
# 898   #Yankees I ain't complaining about the Royals win or lose game7. They showed heart. AL ride or die! No flex zone. They earned it!
# 901   I see ya big Boi in the Oreo V's
# 906   @Stephicans mhmm tweet bird &#128037;
# 910   Early bird catches the worm &#128074;
# 932   @urbasicyabish nigor??
# 948   :) "@PeterDavidsonII: At some point, we need to discuss how delicious the vegan brownie from @busboysandpoets on u St. tastes!"
# 966   last thought before bed: in '92 we had a "mock election" in 3rd grade and i voted for Perot. maybe i related to his really big ears, idk.
# 967   Thw White Iron Band plays this weekend in Fargo,ND at the Aquarium(21+) ,Friday(10-29-10) with Charlie Parr. The next night,Saturday...
# 975   &#8220;@WORSTRAPLYRlCS: http://t.co/hE19TIfqFX&#8221;\n\nHow is this trash...
# 984   @Anotherpotheadd lucky monkey
# 1004  Thank you Charlie, Happy Thursday @Charlie4927 @StacyDmomof5 @PattiSM74 @Kacado @cantUCIMblonde @RevkahJC
# 1011  This music is trash
# 1016  RT @kendramarie91: &#8220;@vngelinaa_: Tornado sirens.... Atleast I'll be dying with you guys @Xo_t33 @a_krizanovic @kendramarie91 &#128557;&#8221; and this ho&#8230;
# 1021  Almost half of North American bird species threatened by climate change http://t.co/dWSYB5BodA http://t.co/F0PVuLNf4c #Climate #Environment
# 1022  @MinuteManX1776 @TheyKnowNotWhat &lt;&lt; closet muzzie @MayberryJustin @AllForCountry @LilMissPrepper @ritzy_jewels @glinsan1
# 1024  @HalleyBrenks3 interesting #hick
# 1030  Wow. No yellow yet? = Pagenaud and Marco screwed. Maybe no yellow coming
# 1039  RT @LuvKittensDaily: Oreo being adorable http://t.co/5ZMZVT0sUl
# 1045  RT @renz360: Got 5 20% off slots for sole sauce for the early birds today \n\nUse &#8220;SAVE20&#8221; at checkout \n \nhttp://t.co/x5bq5vzpPK
# 1048  Jindal seemed to be having an out-of-body experience enhanced by special brownies\nhttp://t.co/W0cyEcqKLo\nBj Up and At 'Em\n#stribpol #mngop
# 1049  @CapitolEVAN That's where I saw the leprechaun. He told me to burn things.
# 1051  Leave it up to me it would've been in the trash.... All of it.
# 1057  Finally got an updated pic with angel wing colored http://t.co/nWN9qRt5Xd
# 1064  RT @PlMPCESS: A silent protest in Philadelphia, performance artists protest the murder of Mike Brown while passerby's mock it. http://t.co/&#8230;
# 1070  5 bags of chips, 3 Rice Krispies, 3 seeds, 3 gummies, a pop tart, some crackers, 3 powerades, and a water yuhhh I'm good lol
# 1077  @cxslug I never did those games, but I was obsessed with Angry birds. Which is why it took me so long to do CCS. I was scared. Lol
# 1084  Looking forward to #NCAA and #NBA basketball &#127936; in the states soon #iubb #hoosiers #pacers #PacerNation and of course breadsticks.
# 1089  Sitting on the deck, enjoying a #StoneIPA, watching/smelling the neighbors burn trash. #Missouri http://t.co/m9wYnrLtWz
# 1101  @ShojoAIE a bright neon yellow gauntlet
# 1103  RT @ProBirdRights: A marry between a man and woman people sloppery slop;then what is prevent a bird from marriage my sandwich??? I'm in lo&#8230;
# 1109  @mark_mac18 @sheppast @rianscalia groves is trash IMO
# 1111  @Lvl_7_Eevee @UnicornCowboy @hisorraya I just wanted brownies man
# 1114  She trash tho.
# 1122  Absolutely absurd that they even had to think about that call. #joke #zebras
# 1150  Swap meet bound #beaner
# 1154  &#8220;@MannyBDlopez: When you open your starburst candy and get 2 yellows http://t.co/F0dDbfEzB6&#8221; lmao bruh
# 1164  RT @BirdGang316: If you a bird throw it up #birdgang #EaglesNation
# 1174  This mint brownies recipe is made with almond flour, coconut palm sugar, coconut oil, and coconut mi http://t.co/XZZfDoLZDn
# 1176  Pic circulating on Jihadi feeds claiming an "ISIS flag" on top of Mount Arafa in the holiest day of pilgrimage http://t.co/46YfuflyZV
# 1177  @tmundal just because some moist bint lobbed a sword at you, you think you're some la-de-da king?
# 1179  RT @robertbevan77: It's like The Walking Dead, but with less Carl and more talking birds. ZOMBIE ATTACK!!! http://t.co/UOCsPyksSC http://t.&#8230;
# 1189  Do you really believe people evolved from apes? &#8212; Not really. I'm quiet convinced with the evolution of man but ... http://t.co/1RswGNpLtc
# 1191  If you a hoe ima treat you like one just like if you're a good girl ima treat you like one. I don't discriminate
# 1203  RT @Dalilaaaaaa__: Flappy birds cheat codes http://t.co/nu6GjYQDJJ
# 1210  Apolonia Gardner of Imperial, CA misspells "phalarope" - a bird that resembles a sandpiper. The dreaded schwa! #spellingbee
# 1223  RT @SneakerPics23: Oreo 6's http://t.co/Jx9DD9oahY
# 1227  Yeah they do. RT @Yankees: Six complete here at The Stadium. #Yankees lead the Red Sox 3-1. #LetsGoYankees
# 1232  RT @Kiaranicole_x: @_JoAries @Kash_WingateLFC @chanchan_ox babes we buy brazilian and Peruvian not Bengali
# 1236  RT @JoeyG_145: Downloaded flappy bird 5 minutes ago... It's already deleted.
# 1241  @c_drew_ I'm guessing so. The players are talking trash.
# 1249  Holy monkey balls its warm today
# 1258  RT @FeinsandNYDN: Yankees acquire Chase Headley from the Padres for Yangervis Solarte and Rafael DePaula.
# 1261  RT @WashTimes: John Kerry caught appearing to mock Israel&#8217;s &#8216;pinpoint&#8217; operation in Gaza - http://t.co/3yqFR9LZsR #Israel #Gaza http://t.co&#8230;
# 1265  RT @NateKlempa: @ROOTSPORTSPIT must not realize how much #WVU games mean to all of us "hillbillies". The @Pirates play 162 games a year. Sh&#8230;
# 1285  @Swamper60 "Happy Happy Helloween, Helloween whoa oh whoa ho" @helloweenorg http://t.co/Tw0jeExqTy
# 1293  Hold all your ghetto labeled and endorsed vodka brands, you can rum me silly any day. \n\n#ShiverMeTimbers
# 1295  This Billy Crystal tribute to Derek Jeter is crazy. I hate the Yankees, but man... Derek Jeter.... #RE2PECT
# 1298  RT @ProBirdRights: i see you again didn't election bird for government, america. that okay. i guess i just take this free cookie for everyo&#8230;
# 1300  @The_Gambit Ha. He ain't welcome in Washington State or Nashville. Serpas is straight trash.
# 1303  RT @TwitchyTeam: Low turnout reported, but Charlie Crist just filed and emergency motion to extend voting hours in Broward Co. http://t.co/&#8230;
# 1316  Is dare any colored players in hockey?
# 1323  RT @49ers: Oregon State WR @brandincooks is a popular #49ers pick in recent mock drafts. \n\nDRAFT TRACKER: http://t.co/AEueKmhkQX http://t.c&#8230;
# 1330  @Alludra_AIE just remember to keep the skirt dark colored. It camouflages all that pan dimensional gore
# 1346  The beautiful Fairy Pools near Glenbrittle on the Isle of Skye, Scotland http://t.co/cyi6xSvn97
# 1356  RT @druggedvibes: Top 5 Thot Tattoos :\n\n1) dream catchers \n\n2) bird feathers \n\n3) inspirational quotes that they dont live by \n\n4) animal p&#8230;
# 1359  My sister told me that I look like a bird. While my past told me that I look like an alien.
# 1360  RT @michaelpshipley: Martin Short On - CONAN - Oct 3, 2014\n\n"With your yellow skin and red hair you look like a #2 pencil."\n\nhttps://t.co/U&#8230;
# 1364  #hoosier fans, is cody zeller nominating for this years #NBA draft? #iubb
# 1402  &#8220;@AbstractLife: @NigelDixon1 @SeanTHarrington Orton is trash idc&#8221; he ain't been playing. Trashlex Smith only sat out Kaep took his spot.
# 1410  U serious bro?? lol RT @CheezMoeJenkinz 2-3:10am early bird special
# 1417  Jihadi streams: British #ISIS fighter identified as Abu Abdurahman Al Britani killed in action. http://t.co/Ksowd8rRCk
# 1418  #mt #goauche #monkey #oldpainting #vinyl #jazz #lounge http://t.co/hueH4HCxx7
# 1426  @Ish_MallyMal @JayJuice22 all trash to me
# 1435  RT @bjs5555: ELECT Democratic Nominee Charlie Brown @Govcharliebrown for #Gov of #TN DEFEAT (R) Gov. Bill Haslam! @UniteBlueTN http://t.co/&#8230;
# 1438  Who needs an alarm when you have the worlds most annoying bird outside your window?!??
# 1443  @b0ssladyre just ate a wees brownie and is seeing random cats
# 1450  Why are people saying don't let guys treat you like a yellow starburst? That's my favorite.
# 1451  CAIR Publishes a Hit List for Jihadis http://t.co/hvVfXypmHm via @RealJTP If you are a red blooded #American you may be on the list..
# 1455  If you've ever been to drunk to fish, you might be a redneck
# 1459  being up at 5am cuz your cat meowed at a nocturnal bird is the ultimate #toughbreak
# 1460  oops: 'constitutionalists' #teabaggers in #mississippi forgot ratify a centerpiece of the constitution: 13th amendment banning slavery.
# 1463  Selling ex lax brownies in front of Meijer to pregnant women. #GoodDeed
# 1464  @mandaxll2963 yellow is even better
# 1465  Damn internal alarm clock. Woke up at 6:35am feeling chunky from my 3am Cheerios splurge. Guilt led me to the treadmill. #Gym #nosleep
# 1468  #tikiti - rough mock for the base of what will eventually be an ashtray @ Tiki Ti http://t.co/8zE8aqY0
# 1475  This one night I was tripping off brownies I put my running shoes on and I was still in pjs, it was 2am ! http://t.co/UwmBpCOMNE
# 1477  @WHAScameradan We might have more. Can't really be sure. But some weird little bird said that might be a possibility. Stay tuned. Maybe.
# 1481  RT @runofplay: I'm confused. Martins Indi just drew a yellow card, but I didn't see him steal a tank from the Brazilian army and open fire &#8230;
# 1485  That warm fuzzy feeling when you're able to give someone a helping hand. Talking about medical problems with others can really help.
# 1490  RT @HMSguy: Rahal's an idiot. Second time this year he's wrecked someone under yellow.
# 1492  @Liveitupjersey BWAHAAAA I just choked on an Oreo cookie!\nI'M figuring, this may have something to do with it! http://t.co/62S7BgMYPX
# 1495  Tommy trash
# 1496  i thought garbage men were supposed to bring trash to the dump but they wouldn't take me ha ha ha. self depreciation ftw.
# 1498  RT @TheRoot: Don Lemon gets called an Uncle Tom, doesn't like it: http://t.co/eV4xgI5Pgc http://t.co/i6Xs8HCnrb
# 1508  This waiting thing is for the birds...
# 1513  Don&#8217;t believe AP&#8217;s ho-hum tone: latest poll is great news for Republicans - Hot Air http://t.co/5HHrFlFP13
# 1518  .@AlyssSmithh @KeveeeD Yes indeed! Camels, ostriches and zebras! Sept. 5-7 http://t.co/X3Oapfm3e8 #VCCamelRaces
# 1521  cut up porkchop, canned pinto beans, a small can of carrots, can of corn, celery, a potato. cayenne powder + crushed red pepper
# 1525  RT @maycie32: @Whitecholo23 np big nig nig
# 1527  Charlie is so adorable. http://t.co/TMpBYyjGFL
# 1530  RT @MarcACaputo: BREAKING: Charlie Crist files emergency motion for a mulligan.
# 1537  @luchadora41 so was slavery, prohibition and not letting women to vote... segregation jim crow laws.. etc etc i can do this all day lol
# 1546  @YoungJeezy got me feelin like #trappin ain't dead. Got me ready to call the #guala! #Salute da truth! #SeenItAll #SeenItAllTheAutobiography
# 1554  @MahNameIsJared be my guest. I want to be a bird I think
# 1557  @Nashgrier purple monkey
# 1558  RT @briangaar: Old white people complaining about government tyranny is like the Yankees being upset that players make too much money
# 1569  RT @bitterarab: Now that Halloween is fast approaching please understand this. We are a culture, not a costume to mock and ridicule! http:/&#8230;
# 1571  RT @AyMrCarter: Apologies trash.. What's understood ain't gotta be explained
# 1582  Your A Good Gravedigger, Charlie Brown #SpookyBroadway @midnight
# 1598  the train station Harry's at is trash I've been to the same Eurostar too they refunded my whole trip to Paris bc train accident
# 1599  RT @ticiaverveer: Royal city of the Kushite kings at Meroe (Sudan),near River Nile.It was the seat of the rulers who occupied Egypt http://&#8230;
# 1602  @Notsosweetpea I like brownies &#128546;
# 1604  Looking back I liked colored better. Let's go back to that
# 1612  One mans trash is another mans treasure
# 1619  Early bird gets the worm right? Hopefully I get a job soon after today! http://t.co/lvgfVBqkdz
# 1627  @Pepper_Redbone @Yankees @Mets Oh yeah. And the annoying damn duck calls?? They outta be banned. Duck horns??
# 1628  RT @JStac825: There's coon classic (R. Kelly, Usher) and then there's classic (Stevie Wonder, Prince). Not that there's anything wrong with&#8230;
# 1633  RT @JohnnyFootbalI: Yeah Kaepernick might have biceps like a Greek God, but the dude looks like he was conceived by a Proboscis monkey http&#8230;
# 1638  Jihadis betting on public protests in Britain to force UK gov out of the anti-ISIS coalition http://t.co/5gJSmrfzWJ
# 1657  if u eat fried eggs and leave the yolk entirely yellow ur a disgrace and also nasty
# 1670  RT @missmollylo: Charlie wears women's clothing
# 1675  RT @Elisaa_Martinez: Happy birthday cotton picker lol @1NOnlyDirtyMike
# 1676  @Misters206 You look like a monkey
# 1682  It's almost Christmas, Charlie Brown...
# 1688  @JonJ_07 like their players really been talking trash about Bama.
# 1698  @Boobah_ they trash
# 1705  I want a slope job so I can get away from everything and be by myself for two weeks. I hate being around people unless they are my friends.
# 1723  it's so weird outside. it's like yellow.
# 1727  RT @LilyBean1313: And I thought I had a problem! #Oreos http://t.co/jfrBKzE1T5
# 1729  @KeiveeB yellow shirt hat turnt to da side
# 1737  wish I had a brownie or a dab to knock me out rn
# 1743  @littlelouie33 eh, take off hoser.
# 1746  @Auroramwj @marylmcaffry @BBAnimals It's a mutation. Genealogy is convoluted. Basically the zebra gene currieries are slaughtered=Extinction
# 1751  Whipped http://t.co/EFSVjPqrwq
# ...
# 3590  cut up porkchop, canned pinto beans, a small can of carrots, can of corn, celery, a potato. cayenne powder + crushed red pepper
# 3594  RT @maycie32: @Whitecholo23 np big nig nig
# 3596  RT @MarcACaputo: BREAKING: Charlie Crist files emergency motion for a mulligan.
# 3604  RT @Perspective_pic: Retweet if you see the bird. http://t.co/o7reXL0teu
# 3615  @YoungJeezy got me feelin like #trappin ain't dead. Got me ready to call the #guala! #Salute da truth! #SeenItAll #SeenItAllTheAutobiography
# 3622  @MahNameIsJared be my guest. I want to be a bird I think
# 3625  I'd be the best at owning a bird. I could teach them the funniest things to say.
# 3626  @Nashgrier purple monkey
# 3627  RT @briangaar: Old white people complaining about government tyranny is like the Yankees being upset that players make too much money
# 3628  this movie is actually good cuz its so retarded
# 3638  RT @bitterarab: Now that Halloween is fast approaching please understand this. We are a culture, not a costume to mock and ridicule! http:/&#8230;
# 3640  RT @AyMrCarter: Apologies trash.. What's understood ain't gotta be explained
# 3649  Your A Good Gravedigger, Charlie Brown #SpookyBroadway @midnight
# 3662  RT @CyFyre: @WesOrrJames love you too my nig #squad
# 3666  the train station Harry's at is trash I've been to the same Eurostar too they refunded my whole trip to Paris bc train accident
# 3667  RT @ShelleT1986: Great start the morning! My daughter danced herself into the coffee table and gave herself a nice shiner... Yea she's a wh&#8230;
# 3668  RT @ticiaverveer: Royal city of the Kushite kings at Meroe (Sudan),near River Nile.It was the seat of the rulers who occupied Egypt http://&#8230;
# 3671  @Notsosweetpea I like brownies &#128546;
# 3680  I'm such a retard sometimes.
# 3681  One mans trash is another mans treasure
# 3683  @ASourAppleTree Have heard hillbilly grousings that bugs much worse in the KV since MIC shut down.
# 3691  Early bird gets the worm right? Hopefully I get a job soon after today! http://t.co/lvgfVBqkdz
# 3699  @Pepper_Redbone @Yankees @Mets Oh yeah. And the annoying damn duck calls?? They outta be banned. Duck horns??
# 3700  RT @JStac825: There's coon classic (R. Kelly, Usher) and then there's classic (Stevie Wonder, Prince). Not that there's anything wrong with&#8230;
# 3703  RT @JohnnyFootbalI: Yeah Kaepernick might have biceps like a Greek God, but the dude looks like he was conceived by a Proboscis monkey http&#8230;
# 3710  Jihadis betting on public protests in Britain to force UK gov out of the anti-ISIS coalition http://t.co/5gJSmrfzWJ
# 3729  if u eat fried eggs and leave the yolk entirely yellow ur a disgrace and also nasty
# 3741  RT @missmollylo: Charlie wears women's clothing
# 3746  RT @Elisaa_Martinez: Happy birthday cotton picker lol @1NOnlyDirtyMike
# 3747  @Misters206 You look like a monkey
# 3755  It's almost Christmas, Charlie Brown...
# 3760  @JonJ_07 like their players really been talking trash about Bama.
# 3773  @Boobah_ they trash
# 3780  I want a slope job so I can get away from everything and be by myself for two weeks. I hate being around people unless they are my friends.
# 3793  The right for an English person to go about his business is more important than any suspicion of some rouge wog cop.
# 3804  RT @LilyBean1313: And I thought I had a problem! #Oreos http://t.co/jfrBKzE1T5
# 3819  @littlelouie33 eh, take off hoser.
# 3822  @Auroramwj @marylmcaffry @BBAnimals It's a mutation. Genealogy is convoluted. Basically the zebra gene currieries are slaughtered=Extinction
# 3826  @caraabastow That's a cute and fuzzy one...hehehe ;)
# 3829  Whipped http://t.co/EFSVjPqrwq
# 3831  RT @chilltweetss: flappy bird is deep... hahaha http://t.co/EMuhmR3jzE
# 3839  Omer Asik so trash on the offensive side of the floor dude real life murky doo doo water
# 3841  #Yankees got beaten by a thug
# 3846  RT @RayHudson: Art thou the bird whom Man loves bestThe pious bird with t/ scarlet breast, Our Robin;that leaves these summer winds sobbing&#8230;
# 3850  Apparently im a honky. Pfft. Like that's a bad thing.
# 3854  @ashleyypat17 if im trash ur trash since we baes now
# 3861  @HBergHattie @snkscoyote I wonder if the progs didn't relegate young black men to the ghettos to keep them away from harry reid's friends...
# 3873  Bet they want a cookie, Bergbrain? You mean like you want a cracker? Kinda bitter here today aren'tcha? #stribpol mngop #mnleg
# 3874  A white lighter is bad luck, not yellow ur stupid
# 3875  RT @SunSentinel: The @SunSentinel Editorial Board endorses Charlie Crist for governor -- Better for Floridians http://t.co/t21z2YBZlQ http:&#8230;
# 3877  Other Jihadi news #ISIS executed #Kuwait preacher Redha Lari coz he was..&#8220;too extreme&#8221; &amp; hampered reconciliation with Nusra with his fatwas
# 3884  RT @Kevineffinskaff: My idea of a diet is eating regular Oreos instead of double stuft and takin off half the cookie (still dip it in 2% ...
# 3886  RT @MTVUK: #Directioners, 1D's @zaynmalik &amp; @Louis_Tomlinson monkey around on set of #StealMyGirl video: http://t.co/sOEbNlR8Re http://t.co&#8230;
# 3889  Is there a looser #college town than #BTown ??? If yes id like to visit #IU #hoosiers
# 3896  RT @Yankees: #Yankees win! Final score: 7-4.
# 3904  Thanks Charlie, have a great evening @Charlie4927 @StacyDmomof5 @RevkahJC @cantUCIMblonde @Kacado @PattiSM74
# 3905  RT @Maxicat: Charlie Rangel Re-Writes History: On GOP &#8220;They Think They Won The Civil War&#8221; http://t.co/moCeUBRUTf
# 3928  RT @jrsalzman: Buzzfeed males who live in the city and buy meat under plastic, mock girls who use guns and go hunting. Who is more manly?
# 3929  Lmaoooooo @ Supreme being trash. Guess Bape is trash to huh?
# 3938  Tomorrow's agenda: bake brownies &amp; visit a couple open house.
# 3943  "Is that an albino Mexican?"\n"No dad, he's Asian."
# 3950  Is Yankee in a good mood today or what
# 3954  Perhaps I'm not a "diehard" Yankee fan, but there's no more point in watching this debacle #Yankees #Tigers #MLB So what else is on? LOL
# 3955  The Bucs has 2 great uniforms and ruined them both for that trash smh
# 3959  So my light was off &amp; door was closed , mom walks in turn lights on . Tells me to take trash out in the morning . then walked out.. Light on
# 3960  Game 126 Preview: Houston #Astros at New York #Yankees http://t.co/sVg7dIIcZG
# 3964  Best rider? That goes to a blaxican.
# 3965  jacob u look like a monkey in dis http://t.co/rkaqn0GRQe
# 3969  Wicked Oreo
# 3971  Be fearful of the wrath of God in a country where many mock Christianity, embrace perversion, abortion, and bows to PC/multiculturalism.
# 3980  Shut up birds it's bed time.
# 3983  @erinscafe Bu I do. I do hate the playa. And the Yankees. If I hate the Yankees for their payroll I have to hate the Dodgers.
# 3985  HOW &#8220;@darrenrovell: Deep Fried Sweet Tea on a graham cracker crust at State Fair of Texas (via @gravweldon) http://t.co/KVzhlmCsls&#8221;
# 3991  RT @lnsaneTweets: when other girls wear beanies they look cute &amp; stylish but when i wear them i look like a member of a drug cartel who sel&#8230;
# 3999  RT @SenorSteez: This whole week was trash
# 4004  RT @Fact: Fake friends are no different than shadows, they stick around during your brightest moments, but disappear during your darkest ho&#8230;
# 4011  i was such a teacher's pet in elementary school. like i brought them cookies and brownies and gave them hugs. im ashamed
# 4014  @EASPORTSFIFA next update, would be AMAZIN if two celebrations were added. 1: Shirt off ( we'll take the yellow) and 2: The RKO
# 4017  RT @PlMPCESS: In the fashion world "urban" definitely means "stolen from black people" it's ghetto on us, and urban on them haha http://t.c&#8230;
# 4032  RT @TheRisingStar23: Shy Glizzy Decent Af
# 4042  @AdamSchein @TheMayorMatt I may have just cried a tad #illmissu shiner
# 4046  Oops, I just had a Freudian slit.
# 4048  @InedibleFood Quickscoping trash. TAKE OF THE TONY HAWK SETUP AND PLAY NORMALLY. THAT'S NOT WHAT SNIPERS ARE FOR!
# 4059  RT @chelseaxlaser: I really need to take my rose colored glasses off though. I gotta stop thinking everybody does shit with good intentions&#8230;
# 4060  @WakeUpPeeps1 Read w/o slant your orig statement said 'everything' we have...that is the only extreme comment made
# 4062  Finished Yankeeography and still hate the Arizona D'backs for winning in 2001, Yankees shoulda had that
# 4081  Western Jihadi fanboys use of language: peppering sentences with Arabic words to sound knowledgeable - #Comical http://t.co/G2rca1XGh7
# 4084  RT @SimpsonsQOTD: &#8220;That's a very nice jig, Kearney. Now isn't dancing much more fun than bullying?" http://t.co/dk7rcqM1FS
# 4089  Good morning Twitter. Make today a positive one. If you can't do that, beat up as many meanie-faces as possible. Also, I hate flappy bird.
# 4112  Lmao RT @iPOSTBADTWEETS: Lowkey Peyton Manning trash

# %%
test_baseline_missed = pd.read_csv('test_baseline_missed.csv', sep='\t')[['tweet','class','prediction']]

# %%
len(test_bnt_hb_combined_correct_hate), len(test_baseline_correct_hate)
# Out:
# (688, 665)

# %%
df_all = pd.concat([test_bnt_hb_combined_correct_hate.set_index('tweet'), test_baseline_correct_hate.set_index('tweet')], 
                   axis='columns', keys=['First', 'Second'])

# %%
df_final = df_all.swaplevel(axis='columns')

# %%
def highlight_diff(data, color='yellow'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('First', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

df_final.style.apply(highlight_diff, axis=None)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_b0785f84_8924_11e9_b279_3c075434fb96" >
# <thead></thead>
# <tbody>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row0" class="row_heading level0 row0" >"@EdgarPixar: Overdosing on heavy drugs doesn't sound bad tonight." I do that pussy shit every day.</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row1" class="row_heading level0 row1" >"@UberFacts: 15 sad TV character deaths we're still bitter over... http://t.co/uLclFUF8nC http://t.co/1RXYQOOsM0"ned stark was the man</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row2" class="row_heading level0 row2" >"@ayyee_ceee_: One mans trash &#128686; is another mans treasure &#127942;"</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row3" class="row_heading level0 row3" >"How about we draft all those gung-ho folks and send them to Afghanistan or other war zones so they can show their... http://t.co/sR1zceHx</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row4" class="row_heading level0 row4" >"Is that an albino Mexican?"
# "No dad, he's Asian."</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row5" class="row_heading level0 row5" >"Your teeth are like the stars." "Aww thanks!" "Yeah... yellow and far away from each other."</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row6" class="row_heading level0 row6" >#NowPlaying : BT feat. Tori Amos - Blue Skies (radio edit) on #1069TheArrow - http://t.co/R5wuXA9jB6</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row7" class="row_heading level0 row7" >#WorldSeriesGame3 Hunter Pence is so annoying he should be a Red Sox player. Shave fool and take your Vyvanse&#9918;&#65039;&#9918;&#65039;&#128074;&#128074;#Yankees 2015!!</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row8" class="row_heading level0 row8" >#Yankees Damn. Well Joe that move to the bullpen really helped.</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row9" class="row_heading level0 row9" >#Yankees I ain't complaining about the Royals win or lose game7. They showed heart. AL ride or die! No flex zone. They earned it!</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row10" class="row_heading level0 row10" >#Yankees Pineda needed that 6'7. Great play!</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row11" class="row_heading level0 row11" >#Yankees got beaten by a thug</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row12" class="row_heading level0 row12" >#hoosier fans, is cody zeller nominating for this years #NBA draft? #iubb</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row13" class="row_heading level0 row13" >#mt #goauche #monkey #oldpainting #vinyl #jazz #lounge http://t.co/hueH4HCxx7</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row14" class="row_heading level0 row14" >#tikiti - rough mock for the base of what will eventually be an ashtray @ Tiki Ti http://t.co/8zE8aqY0</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row15" class="row_heading level0 row15" >&#128514;&#128514; maaaaannnn i hope so! RT @ABrown252: @VonshayeB did we get rid of John Legend looking Charlie Batch?</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row16" class="row_heading level0 row16" >&#8220;@AbstractLife: @NigelDixon1 @SeanTHarrington Orton is trash idc&#8221; he ain't been playing. Trashlex Smith only sat out Kaep took his spot.</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row17" class="row_heading level0 row17" >&#8220;@CommonBlackGirI: here&#8217;s to all the kids who have never found their name on anything in a souvenir store&#8221; thanks mom for the ghetto name.</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row18" class="row_heading level0 row18" >&#8220;@HeyKeifer: Oreos are basically dirt circles with cream.&#8221; True.</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row19" class="row_heading level0 row19" >&#8220;@HumbleTeej: @elisabethepps where am I on this rating scale???&#8221; Depends. You still wearing them colored contacts or naw?</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row20" class="row_heading level0 row20" >&#8220;@MannyBDlopez: When you open your starburst candy and get 2 yellows http://t.co/F0dDbfEzB6&#8221; lmao bruh</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row21" class="row_heading level0 row21" >&#8220;@TWOLVEGIRL: I find myself wanting to google "the yellow king" #TrueDetective&#8221; No kidding! What is going on?</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row22" class="row_heading level0 row22" >&#8220;@WORSTRAPLYRlCS: http://t.co/hE19TIfqFX&#8221;
#
# How is this trash...</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row23" class="row_heading level0 row23" >&#8220;@anallanusa32: 83 you're really cool you're good at basketball. And your a zebra &#127936;&#128060;&#8221; is this @WillBall4Life?</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row24" class="row_heading level0 row24" >&#8220;@iCARLEYBBY: &#8220;@DJZeeti: twitpic a selfie with light colored eyes&#8221; http://t.co/BSOYlL83Iz&#8221;&#128525;</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row25" class="row_heading level0 row25" >&#8220;@wassssupsarah: Car hopping is a different world these ghetto guys tried asking for my number LOL&#8221; did they have to be ghetto Tho ?</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row26" class="row_heading level0 row26" >&#8220;@wizkhalifa: On the east coast there's colored hair everywhere.
#
# This must be the sweetest wave ever.&#8221; @LayaFace</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row27" class="row_heading level0 row27" >&#8220;@wwwobert_: B Oreo a stunt&#8221;come thru &#128293;&#128293;&#128293;</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row28" class="row_heading level0 row28" >&#9733; BEST ASIAN MASSAGE ON THE park slope --TOP RATED SPA &#9733; 718-622-0221 - 24 http://t.co/Nkvy9nwyzj</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row29" class="row_heading level0 row29" >.@AlyssSmithh @KeveeeD Yes indeed! Camels, ostriches and zebras! Sept. 5-7 http://t.co/X3Oapfm3e8 #VCCamelRaces</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row30" class="row_heading level0 row30" >5 bags of chips, 3 Rice Krispies, 3 seeds, 3 gummies, a pop tart, some crackers, 3 powerades, and a water yuhhh I'm good lol</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row31" class="row_heading level0 row31" >:) "@PeterDavidsonII: At some point, we need to discuss how delicious the vegan brownie from @busboysandpoets on u St. tastes!"</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row32" class="row_heading level0 row32" >@1Corinthians126 #BooksOfGodWidom Proverbs 1:26 I also will laugh at your calamity; I will mock when your fear cometh;</th>
#     </tr>    <tr>
#         <th id="T_b0785f84_8924_11e9_b279_3c075434fb96level0_row33" class="row_heading level0 row33" >@1Corinthians126 #Jesus Genesis 2:19 Out of the groun

# %%
df_final

# %%
m = test_bnt_hb_combined_correct_hate.merge(test_baseline_correct.drop_duplicates(),how='outer',indicator=True)

# %%
m
# Out:
#                                                                                                                                                                                                                                                                tweet  \
# 0     RT @DamnFoodPorn: Oreo Cookie Pancakes #FoodPorn http://t.co/q6EvCvM3sO
# 1     RT @DamnFoodPorn: Oreo Cookie Pancakes #FoodPorn http://t.co/q6EvCvM3sO
# 2     Fairy Tale Hat - free crochet pattern for child and adult at http://t.co/0lRaBLMHB2 http://t.co/99zVbmYVe9
# 3     Fairy Tale Hat - free crochet pattern for child and adult at http://t.co/0lRaBLMHB2 http://t.co/99zVbmYVe9
# 4     Fairy Tale Hat - free crochet pattern for child and adult at http://t.co/0lRaBLMHB2 http://t.co/99zVbmYVe9
# 5     Fairy Tale Hat - free crochet pattern for child and adult at http://t.co/0lRaBLMHB2 http://t.co/99zVbmYVe9
# 6     RT @daraobriain: Tommy Voeckler keeps the yellow, Andy Schleck does the break of the tour, and Contador is broken. Incredible day for #tdf
# 7     RT @daraobriain: Tommy Voeckler keeps the yellow, Andy Schleck does the break of the tour, and Contador is broken. Incredible day for #tdf
# 8     RT @daraobriain: Tommy Voeckler keeps the yellow, Andy Schleck does the break of the tour, and Contador is broken. Incredible day for #tdf
# 9     RT @daraobriain: Tommy Voeckler keeps the yellow, Andy Schleck does the break of the tour, and Contador is broken. Incredible day for #tdf
# 10    Watching #Steelers colts getting blinded by the Steelers uniys look like bunch of bumblebees
# 11    Watching #Steelers colts getting blinded by the Steelers uniys look like bunch of bumblebees
# 12    Watching #Steelers colts getting blinded by the Steelers uniys look like bunch of bumblebees
# 13    Watching #Steelers colts getting blinded by the Steelers uniys look like bunch of bumblebees
# 14    RT @netflix: Here's your first look at Charlie Cox as Matt Murdock in #Marvel's @Daredevil on #Netflix #NYCC http://t.co/SIYuCgok8J
# 15    RT @netflix: Here's your first look at Charlie Cox as Matt Murdock in #Marvel's @Daredevil on #Netflix #NYCC http://t.co/SIYuCgok8J
# 16    RT @netflix: Here's your first look at Charlie Cox as Matt Murdock in #Marvel's @Daredevil on #Netflix #NYCC http://t.co/SIYuCgok8J
# 17    RT @netflix: Here's your first look at Charlie Cox as Matt Murdock in #Marvel's @Daredevil on #Netflix #NYCC http://t.co/SIYuCgok8J
# 18    It's a matter of pure weight ratios... A five ounce bird can not carry a one pound coconut!
# 19    It's a matter of pure weight ratios... A five ounce bird can not carry a one pound coconut!
# 20    Ravioli stuffed wit lobster nd a nice stuffed clam #eating betterthanamobster http://t.co/PzdoESaR
# 21    Ravioli stuffed wit lobster nd a nice stuffed clam #eating betterthanamobster http://t.co/PzdoESaR
# 22    @AB_crispyy_andy I laugh Oreos and lady gaga on a Sunday day
# 23    @AB_crispyy_andy I laugh Oreos and lady gaga on a Sunday day
# 24    #Yankees Damn. Well Joe that move to the bullpen really helped.
# 25    #Yankees Damn. Well Joe that move to the bullpen really helped.
# 26    #Yankees Damn. Well Joe that move to the bullpen really helped.
# 27    #Yankees Damn. Well Joe that move to the bullpen really helped.
# 28    Next time you leave magic trash in my jacket try not to have your initials written on them. @whatupag http://t.co/tFV1cZtr
# 29    Next time you leave magic trash in my jacket try not to have your initials written on them. @whatupag http://t.co/tFV1cZtr
# 30    Next time you leave magic trash in my jacket try not to have your initials written on them. @whatupag http://t.co/tFV1cZtr
# 31    Next time you leave magic trash in my jacket try not to have your initials written on them. @whatupag http://t.co/tFV1cZtr
# 32    Yankees getting killed
# 33    Yankees getting killed
# 34    Yankees getting killed
# 35    Yankees getting killed
# 36    Islamic Jihadis run away to Pakistan @PureMonotheist @BemetOr8 #UniteBlue
# 37    Islamic Jihadis run away to Pakistan @PureMonotheist @BemetOr8 #UniteBlue
# 38    Islamic Jihadis run away to Pakistan @PureMonotheist @BemetOr8 #UniteBlue
# 39    Islamic Jihadis run away to Pakistan @PureMonotheist @BemetOr8 #UniteBlue
# 40    RT @Shalewis09: Larry Elder is an Uncle Tom. I cannot believe how he is degrading a child.
# 41    RT @Shalewis09: Larry Elder is an Uncle Tom. I cannot believe how he is degrading a child.
# 42    RT @Shalewis09: Larry Elder is an Uncle Tom. I cannot believe how he is degrading a child.
# 43    RT @Shalewis09: Larry Elder is an Uncle Tom. I cannot believe how he is degrading a child.
# 44    RT @koolestbreeze: Thanks Charlie!! http://t.co/iw06cCEkND
# 45    RT @koolestbreeze: Thanks Charlie!! http://t.co/iw06cCEkND
# 46    RT @koolestbreeze: Thanks Charlie!! http://t.co/iw06cCEkND
# 47    RT @koolestbreeze: Thanks Charlie!! http://t.co/iw06cCEkND
# 48    @rochaaxx yellow
# 49    @rochaaxx yellow
# 50    @rochaaxx yellow
# 51    @rochaaxx yellow
# 52    RT @HoodJesusYo: Last name, Sinner\nFirst name, Imma\nLike ur pancakes in tha mornin, \nHe got u covered like Aunt Jemima
# 53    RT @HoodJesusYo: Last name, Sinner\nFirst name, Imma\nLike ur pancakes in tha mornin, \nHe got u covered like Aunt Jemima
# 54    RT @HoodJesusYo: Last name, Sinner\nFirst name, Imma\nLike ur pancakes in tha mornin, \nHe got u covered like Aunt Jemima
# 55    RT @HoodJesusYo: Last name, Sinner\nFirst name, Imma\nLike ur pancakes in tha mornin, \nHe got u covered like Aunt Jemima
# 56    RT @chilltweetss: when I make the paper ball into the trash can &#128168; http://t.co/Xnx2XEGACm
# 57    RT @chilltweetss: when I make the paper ball into the trash can &#128168; http://t.co/Xnx2XEGACm
# 58    RT @chilltweetss: when I make the paper ball into the trash can &#128168; http://t.co/Xnx2XEGACm
# 59    RT @chilltweetss: when I make the paper ball into the trash can &#128168; http://t.co/Xnx2XEGACm
# 60    Jay Z - Takeover &amp; U Don't Know LIVE @ Home &amp; Home Concert Yankee Stadium: http://t.co/4EuK80uLiS via @YouTube
# 61    Jay Z - Takeover &amp; U Don't Know LIVE @ Home &amp; Home Concert Yankee Stadium: http://t.co/4EuK80uLiS via @YouTube
# 62    Jay Z - Takeover &amp; U Don't Know LIVE @ Home &amp; Home Concert Yankee Stadium: http://t.co/4EuK80uLiS via @YouTube
# 63    Jay Z - Takeover &amp; U Don't Know LIVE @ Home &amp; Home Concert Yankee Stadium: http://t.co/4EuK80uLiS via @YouTube
# 64    Noap. Not taking them. RT @TiffNCompany: Maca root pills making my vagina do the wop
# 65    Noap. Not taking them. RT @TiffNCompany: Maca root pills making my vagina do the wop
# 66    Noap. Not taking them. RT @TiffNCompany: Maca root pills making my vagina do the wop
# 67    Noap. Not taking them. RT @TiffNCompany: Maca root pills making my vagina do the wop
# 68    @_BradleyC skate 2 trash :(:( skate 3 had goat DLC
# 69    @JonnieSantana He's definitely trash. But if Bill Cohwer or Stanford 's head coach want the job I'd hire them. With a new gm of course
# 70    @JonnieSantana He's definitely trash. But if Bill Cohwer or Stanford 's head coach want the job I'd hire them. With a new gm of course
# 71    @JonnieSantana He's definitely trash. But if Bill Cohwer or Stanford 's head coach want the job I'd hire them. With a new gm of course
# 72    @JonnieSantana He's definitely trash. But if Bill Cohwer or Stanford 's head coach want the job I'd hire them. With a new gm of course
# 73    This Charlie Murder game is pretty dope #Xbla
# 74    This Charlie Murder game is pretty dope #Xbla
# 75    This Charlie Murder game is pretty dope #Xbla
# 76    This Charlie Murder game is pretty dope #Xbla
# 77    RT @TomBradysEgo: Might have a better chance if we put some trash cans out there.
# 78    RT @TomBradysEgo: Might have a better chance if we put some trash cans out there.
# 79    @Buckm00se @LEXXX_RUGER @ivanrabago_ the kikes want to charge you &#128175; dollaz for the complete version http://t.co/ZJDLwiAjEo
# 80    @Buckm00se @LEXXX_RUGER @ivanrabago_ the kikes want to charge you &#128175; dollaz for the complete version http://t.co/ZJDLwiAjEo
# 81    @Buckm00se @LEXXX_RUGER @ivanrabago_ the kikes want to charge you &#128175; dollaz for the complete version http://t.co/ZJDLwiAjEo
# 82    @Buckm00se @LEXXX_RUGER @ivanrabago_ the kikes want to charge you &#128175; dollaz for the complete version http://t.co/ZJDLwiAjEo
# 83    @louiev_ lol just getting this..early bird catches the worm!
# 84    @louiev_ lol just getting this..early bird catches the worm!
# 85    @louiev_ lol just getting this..early bird catches the worm!
# 86    @louiev_ lol just getting this..early bird catches the worm!
# 87    @XxminijokerXx I HATE birds! They just piss me off about the fact that I can't fly!
# 88    bae won his game &#128525; #redskins
# 89    bae won his game &#128525; #redskins
# 90    bae won his game &#128525; #redskins
# 91    bae won his game &#128525; #redskins
# 92    Oriental rugs cause I'm flyer than a dove.
# 93    Oriental rugs cause I'm flyer than a dove.
# 94    Oriental rugs cause I'm flyer than a dove.
# 95    Oriental rugs cause I'm flyer than a dove.
# 96    @washingtonpost The people who work at those companies tend to be trash.
# 97    @washingtonpost The people who work at those companies tend to be trash.
# 98    @washingtonpost The people who work at those companies tend to be trash.
# 99    @washingtonpost The people who work at those companies tend to be trash.
# 100   RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;
# 101   RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;
# 102   RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;
# 103   RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;
# 104   RT @NickSwagyPYoung: Happy Halloween from Rick James (aka Swaggy) and Charlie Murphy ( @bigmeat2000 ) haha darkness everybody http://t.co/y&#8230;
# 105   RT @NickSwagyPYoung: Happy Halloween from Rick James (aka Swaggy) and Charlie Murphy ( @bigmeat2000 ) haha darkness everybody http://t.co/y&#8230;
# 106   RT @MaryWCVB: Still waiting for Charlie Baker to take the stage in Swampscott. #wcvb http://t.co/lYb3Thm199
# 107   RT @MaryWCVB: Still waiting for Charlie Baker to take the stage in Swampscott. #wcvb http://t.co/lYb3Thm199
# 108   RT @MaryWCVB: Still waiting for Charlie Baker to take the stage in Swampscott. #wcvb http://t.co/lYb3Thm199
# 109   RT @MaryWCVB: Still waiting for Charlie Baker to take the stage in Swampscott. #wcvb http://t.co/lYb3Thm199
# 110   Tuna is good the rest trash RT @AyeoFool: Cans of spam RT @MsBTxo: Most struggle food HAS TO BE any meat In a can, tuna included
# 111   Tuna is good the rest trash RT @AyeoFool: Cans of spam RT @MsBTxo: Most struggle food HAS TO BE any meat In a can, tuna included
# 112   RT @CHlLDHOODRUINER: she paid $5 to hold the monkey and look what he did &#128514;&#128557;&#128553; this monkey real af http://t.co/NgeCuWehHb
# 113   RT @CHlLDHOODRUINER: she paid $5 to hold the monkey and look what he did &#128514;&#128557;&#128553; this monkey real af http://t.co/NgeCuWehHb
# 114   We over here struggling with college and work and ice jj fish making money for being trash lol. What has this world come to.
# 115   We over here struggling with college and work and ice jj fish making money for being trash lol. What has this world come to.
# 116   First jig of the night
# 117   First jig of the night
# 118   First jig of the night
# 119   First jig of the night
# 120   RT @sportswithjohn: Dani Alves uses his new gray hair to talk himself out of a yellow card, telling the referee, "I am but a humble senior &#8230;
# 121   "@UberFacts: 15 sad TV character deaths we're still bitter over... http://t.co/uLclFUF8nC http://t.co/1RXYQOOsM0"ned stark was the man
# 122   "@UberFacts: 15 sad TV character deaths we're still bitter over... http://t.co/uLclFUF8nC http://t.co/1RXYQOOsM0"ned stark was the man
# 123   MT: "@DocKozlowski: Ted Cruz "We are proud wacko birds". #StandWithCruz #KeepCruzing" is that a pun?
# 124   MT: "@DocKozlowski: Ted Cruz "We are proud wacko birds". #StandWithCruz #KeepCruzing" is that a pun?
# 125   MT: "@DocKozlowski: Ted Cruz "We are proud wacko birds". #StandWithCruz #KeepCruzing" is that a pun?
# 126   MT: "@DocKozlowski: Ted Cruz "We are proud wacko birds". #StandWithCruz #KeepCruzing" is that a pun?
# 127   RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0
# 128   RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0
# 129   RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0
# 130   RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0
# 131   @hxhsharingan666 did you make an animal cracker taco
# 132   @hxhsharingan666 did you make an animal cracker taco
# 133   can my cat not kill birds and make a huge mes of feathers
# 134   can my cat not kill birds and make a huge mes of feathers
# 135   can my cat not kill birds and make a huge mes of feathers
# 136   can my cat not kill birds and make a huge mes of feathers
# 137   No more speculation. No more mock drafts. It's finally Draft Day. #BortlesKombat #StormWarning #BuiltByUCF #ChargeOn
# 138   No more speculation. No more mock drafts. It's finally Draft Day. #BortlesKombat #StormWarning #BuiltByUCF #ChargeOn
# 139   @OldManRo you should check it out... it aint animated and has Charlie Murphy in it
# 140   @wodaeeex3 it didnt open das y i asked cus i thought yu ate wat i had Pork chops yellow rice n beans
# 141   @wodaeeex3 it didnt open das y i asked cus i thought yu ate wat i had Pork chops yellow rice n beans
# 142   Early worm gets the bird #Bslfe #GoodMorning http://t.co/dfE8MF2Q28
# 143   Early worm gets the bird #Bslfe #GoodMorning http://t.co/dfE8MF2Q28
# 144   Early worm gets the bird #Bslfe #GoodMorning http://t.co/dfE8MF2Q28
# 145   Early worm gets the bird #Bslfe #GoodMorning http://t.co/dfE8MF2Q28
# 146   I ate a monkey. #AndNowIHaveEbola
# 147   Charlie Rangel: Some Republicans 'Believe That Slavery Isn't Over' | Truth Revolt: http://t.co/NpbdPk0Cqz \nBam, Race Card Vote Democrats out
# 148   Charlie Rangel: Some Republicans 'Believe That Slavery Isn't Over' | Truth Revolt: http://t.co/NpbdPk0Cqz \nBam, Race Card Vote Democrats out
# 149   Charlie Rangel: Some Republicans 'Believe That Slavery Isn't Over' | Truth Revolt: http://t.co/NpbdPk0Cqz \nBam, Race Card Vote Democrats out
# 150   Charlie Rangel: Some Republicans 'Believe That Slavery Isn't Over' | Truth Revolt: http://t.co/NpbdPk0Cqz \nBam, Race Card Vote Democrats out
# 151   RT @RudeBoi_Drew: @PAPER_CHAYSIN condom were invent for that sole purpose
# 152   RT @RudeBoi_Drew: @PAPER_CHAYSIN condom were invent for that sole purpose
# 153   Whoever mocks the poor insults his Maker; he who is glad at calamity will not go unpunished. http://t.co/P7zwAoXi4l
# 154   Whoever mocks the poor insults his Maker; he who is glad at calamity will not go unpunished. http://t.co/P7zwAoXi4l
# 155   RT @MindOnSuccess_: My mother be on some trash man &#128514; I ask her EVERYDAY, you need/ want some money? She say "Naw I'm good!" But come payday&#8230;
# 156   RT @MindOnSuccess_: My mother be on some trash man &#128514; I ask her EVERYDAY, you need/ want some money? She say "Naw I'm good!" But come payday&#8230;
# 157   RT @MindOnSuccess_: My mother be on some trash man &#128514; I ask her EVERYDAY, you need/ want some money? She say "Naw I'm good!" But come payday&#8230;
# 158   RT @MindOnSuccess_: My mother be on some trash man &#128514; I ask her EVERYDAY, you need/ want some money? She say "Naw I'm good!" But come payday&#8230;
# 159   RT @Macbeth870: #bowebergdahl There hasn't been a trade this lopsided since Babe Ruth was traded to the Yankees for "No No Nanette" cash.
# 160   RT @Macbeth870: #bowebergdahl There hasn't been a trade this lopsided since Babe Ruth was traded to the Yankees for "No No Nanette" cash.
# 161   RT @Macbeth870: #bowebergdahl There hasn't been a trade this lopsided since Babe Ruth was traded to the Yankees for "No No Nanette" cash.
# 162   RT @Macbeth870: #bowebergdahl There hasn't been a trade this lopsided since Babe Ruth was traded to the Yankees for "No No Nanette" cash.
# 163   Got chunky marmalade today of a greatful customer for my service over the past 2 yrs #PostieTweet #ServiceMatters http://t.co/pSEnGvyxrw
# 164   Got chunky marmalade today of a greatful customer for my service over the past 2 yrs #PostieTweet #ServiceMatters http://t.co/pSEnGvyxrw
# 165   RT @lowcountry_luv: Attack animals, last house on the left by the lake, and she got colored eyes...we should have known.! Lol
# 166   RT @lowcountry_luv: Attack animals, last house on the left by the lake, and she got colored eyes...we should have known.! Lol
# 167   RT @lowcountry_luv: Attack animals, last house on the left by the lake, and she got colored eyes...we should have known.! Lol
# 168   RT @lowcountry_luv: Attack animals, last house on the left by the lake, and she got colored eyes...we should have known.! Lol
# 169   RT @foodbibIe: Oreo Cheesecake http://t.co/yW299XjzB2
# 170   RT @foodbibIe: Oreo Cheesecake http://t.co/yW299XjzB2
# 171   RT @foodbibIe: Oreo Cheesecake http://t.co/yW299XjzB2
# 172   RT @foodbibIe: Oreo Cheesecake http://t.co/yW299XjzB2
# 173   @boxingscene @RPopBox @BronzeBomber @boxing this Charlie Z really does need mental help check this out http://t.co/CkBS6WcZu1
# 174   @boxingscene @RPopBox @BronzeBomber @boxing this Charlie Z really does need mental help check this out http://t.co/CkBS6WcZu1
# 175   @teapot Great GIF. Got a source URL for @gifs?
# 176   @teapot Great GIF. Got a source URL for @gifs?
# 177   Nothing good on TV and the @Yankees are eating their balls 3 innings in. Great.
# 178   That was trash. I'm just gonna put my phone down. Goodnight
# 179   That was trash. I'm just gonna put my phone down. Goodnight
# ...
# 281   2.0    0.0         both
# 282   2.0    2.0         both
# 283   2.0    1.0         both
# 284   2.0    2.0         both
# 285   2.0    1.0         both
# 286   2.0    2.0         both
# 287   2.0    2.0         both
# 288   2.0    2.0         both
# 289   2.0    1.0         both
# 290   2.0    2.0         both
# 291   2.0    1.0         both
# 292   2.0    2.0         both
# 293   2.0    2.0         both
# 294   2.0    2.0         both
# 295   2.0    2.0         both
# 296   2.0    2.0         both
# 297   2.0    1.0         both
# 298   2.0    2.0         both
# 299   2.0    1.0         both
# 300   2.0    2.0         both
# 301   2.0    2.0         both
# 302   2.0    1.0         both
# 303   2.0    2.0         both
# 304   2.0    1.0         both
# 305   2.0    2.0         both
# 306   2.0    1.0         both
# 307   2.0    2.0         both
# 308   2.0    1.0         both
# 309   2.0    2.0         both
# 310   2.0    1.0         both
# 311   2.0    2.0         both
# 312   2.0    1.0         both
# 313   2.0    2.0         both
# 314   2.0    2.0         both
# 315   2.0    1.0         both
# 316   2.0    2.0         both
# 317   2.0    1.0         both
# 318   2.0    2.0         both
# 319   2.0    1.0         both
# 320   2.0    2.0         both
# 321   2.0    1.0         both
# 322   2.0    2.0         both
# 323   2.0    1.0         both
# 324   2.0    2.0         both
# 325   2.0    1.0         both
# 326   2.0    2.0         both
# 327   2.0    1.0         both
# 328   2.0    2.0         both
# 329   2.0    1.0         both
# 330   2.0    2.0         both
# 331   2.0    1.0         both
# 332   2.0    2.0         both
# 333   2.0    1.0         both
# 334   2.0    2.0         both
# 335   2.0    1.0         both
# 336   2.0    2.0         both
# 337   2.0    2.0         both
# 338   2.0    2.0         both
# 339   2.0    2.0         both
# 340   2.0    2.0         both
# 341   2.0    2.0         both
# 342   2.0    2.0         both
# 343   2.0    1.0         both
# 344   2.0    2.0         both
# 345   2.0    1.0         both
# 346   2.0    2.0         both
# 347   2.0    1.0         both
# 348   2.0    1.0         both
# 349   2.0    2.0         both
# ...   ...    ...          ...
# 3095  1.0    1.0         right_only
# 3096  1.0    1.0         right_only
# 3097  1.0    1.0         right_only
# 3098  1.0    2.0         right_only
# 3099  1.0    1.0         right_only
# 3100  1.0    1.0         right_only
# 3101  1.0    1.0         right_only
# 3102  1.0    1.0         right_only
# 3103  1.0    1.0         right_only
# 3104  1.0    1.0         right_only
# 3105  1.0    1.0         right_only
# 3106  1.0    1.0         right_only
# 3107  1.0    1.0         right_only
# 3108  1.0    1.0         right_only
# 3109  0.0    0.0         right_only
# 3110  0.0    1.0         right_only
# 3111  1.0    1.0         right_only
# 3112  1.0    1.0         right_only
# 3113  1.0    0.0         right_only
# 3114  1.0    1.0         right_only
# 3115  1.0    1.0         right_only
# 3116  1.0    2.0         right_only
# 3117  1.0    1.0         right_only
# 3118  1.0    1.0         right_only
# 3119  1.0    1.0         right_only
# 3120  1.0    1.0         right_only
# 3121  1.0    1.0         right_only
# 3122  1.0    1.0         right_only
# 3123  1.0    1.0         right_only
# 3124  1.0    1.0         right_only
# 3125  1.0    1.0         right_only
# 3126  1.0    1.0         right_only
# 3127  1.0    2.0         right_only
# 3128  1.0    1.0         right_only
# 3129  1.0    1.0         right_only
# 3130  1.0    1.0         right_only
# 3131  1.0    1.0         right_only
# 3132  1.0    1.0         right_only
# 3133  1.0    1.0         right_only
# 3134  1.0    1.0         right_only
# 3135  1.0    1.0         right_only
# 3136  1.0    1.0         right_only
# 3137  1.0    1.0         right_only
# 3138  1.0    1.0         right_only
# 3139  1.0    1.0         right_only
# 3140  1.0    1.0         right_only
# 3141  1.0    2.0         right_only
# 3142  1.0    1.0         right_only
# 3143  1.0    1.0         right_only
# 3144  1.0    1.0         right_only
# 3145  1.0    1.0         right_only
# 3146  1.0    2.0         right_only
# 3147  1.0    1.0         right_only
# 3148  0.0    1.0         right_only
# 3149  1.0    1.0         right_only
# 3150  1.0    2.0         right_only
# 3151  1.0    1.0         right_only
# 3152  0.0    1.0         right_only
# 3153  1.0    1.0         right_only
# 3154  1.0    1.0         right_only
# 3155  1.0    1.0         right_only
# 3156  1.0    1.0         right_only
# 3157  1.0    1.0         right_only
# 3158  0.0    1.0         right_only
# 3159  1.0    1.0         right_only
# 3160  1.0    2.0         right_only
# 3161  1.0    2.0         right_only
# 3162  1.0    1.0         right_only
# 3163  0.0    1.0         right_only
# 3164  1.0    2.0         right_only
# 3165  1.0    1.0         right_only
# 3166  1.0    1.0         right_only
# 3167  1.0    2.0         right_only
# 3168  2.0    1.0         right_only
# 3169  1.0    1.0         right_only
# 3170  1.0    1.0         right_only
# 3171  1.0    1.0         right_only
# 3172  1.0    1.0         right_only
# 3173  1.0    2.0         right_only
# 3174  1.0    1.0         right_only
# 3175  1.0    1.0         right_only
# 3176  1.0    2.0         right_only
# 3177  1.0    1.0         right_only
# 3178  0.0    2.0         right_only
# 3179  1.0    1.0         right_only
# 3180  1.0    1.0         right_only
# 3181  1.0    1.0         right_only
# 3182  1.0    1.0         right_only
# 3183  1.0    1.0         right_only
# 3184  1.0    1.0         right_only
# 3185  1.0    1.0         right_only
# 3186  1.0    2.0         right_only
# 3187  0.0    1.0         right_only
# 3188  1.0    2.0         right_only
# 3189  1.0    1.0         right_only
# 3190  1.0    1.0         right_only
# 3191  1.0    1.0         right_only
# 3192  1.0    1.0         right_only
# 3193  1.0    1.0         right_only
# 3194  1.0    2.0         right_only
# 3195  0.0    1.0         right_only
# 3196  1.0    1.0         right_only
# 3197  1.0    1.0         right_only
# 3198  0.0    1.0         right_only
# 3199  1.0    1.0         right_only
# 3200  1.0    2.0         right_only
# 3201  1.0    1.0         right_only
# 3202  1.0    1.0         right_only
# 3203  1.0    1.0         right_only
# 3204  1.0    1.0         right_only
# 3205  1.0    1.0         right_only
# 3206  0.0    1.0         right_only
# 3207  1.0    2.0         right_only
# 3208  1.0    1.0         right_only
# 3209  1.0    1.0         right_only
# 3210  1.0    1.0         right_only
# 3211  1.0    1.0         right_only
# 3212  1.0    1.0         right_only
# 3213  1.0    2.0         right_only
# 3214  1.0    1.0         right_only
# 3215  1.0    1.0         right_only
# 3216  0.0    1.0         right_only
# 3217  0.0    1.0         right_only
# 3218  1.0    1.0         right_only
# 3219  1.0    2.0         right_only
# 3220  1.0    1.0         right_only
# 3221  1.0    2.0         right_only
# 3222  1.0    2.0         right_only
# 3223  1.0    1.0         right_only
# 3224  1.0    1.0         right_only
# 3225  0.0    1.0         right_only
# 3226  1.0    1.0         right_only
# 3227  1.0    1.0         right_only
# 3228  1.0    1.0         right_only
# 3229  1.0    1.0         right_only
# 3230  1.0    1.0         right_only
# 3231  1.0    0.0         right_only
# 3232  1.0    2.0         right_only
# 3233  0.0    1.0         right_only
# 3234  1.0    1.0         right_only
# 3235  1.0    1.0         right_only
# 3236  1.0    1.0         right_only
# 3237  1.0    1.0         right_only
# 3238  1.0    1.0         right_only
# 3239  1.0    1.0         right_only
# 3240  1.0    1.0         right_only
# 3241  1.0    2.0         right_only
# 3242  1.0    1.0         right_only
# 3243  0.0    1.0         right_only
# 3244  0.0    1.0         right_only
# 3245  1.0    1.0         right_only
# 3246  1.0    2.0         right_only
# 3247  1.0    2.0         right_only
# 3248  1.0    1.0         right_only
# 3249  1.0    0.0         right_only
# 3250  1.0    1.0         right_only
# 3251  1.0    2.0         right_only
# 3252  0.0    1.0         right_only
# 3253  0.0    1.0         right_only
# 3254  1.0    2.0         right_only
# 3255  1.0    0.0         right_only
# 3256  1.0    1.0         right_only
# 3257  1.0    1.0         right_only
# 3258  1.0    1.0         right_only
# 3259  0.0    1.0         right_only
# 3260  1.0    1.0         right_only
# 3261  1.0    2.0         right_only
# 3262  1.0    2.0         right_only
# 3263  1.0    2.0         right_only
# 3264  1.0    0.0         right_only
# 3265  0.0    1.0         right_only
# 3266  1.0    2.0         right_only
# 3267  0.0    0.0         right_only
# 3268  1.0    1.0         right_only
# 3269  1.0    1.0         right_only
# 3270  1.0    2.0         right_only
# 3271  1.0    1.0         right_only
# 3272  1.0    2.0         right_only
# 3273  1.0    1.0         right_only
# 3274  1.0    1.0         right_only
# 3275  1.0    2.0         right_only
# 3276  0.0    1.0         right_only
# 3277  1.0    2.0         right_only
# 3278  1.0    0.0         right_only
# 3279  1.0    1.0         right_only
# 3280  1.0    1.0         right_only
# 3281  1.0    2.0         right_only
# 3282  1.0    1.0         right_only
# 3283  1.0    2.0         right_only
# 3284  1.0    1.0         right_only
# 3285  1.0    1.0         right_only
# 3286  1.0    1.0         right_only
# 3287  0.0    1.0         right_only
# 3288  0.0    1.0         right_only
# 3289  1.0    1.0         right_only
# 3290  1.0    1.0         right_only
# 3291  1.0    1.0         right_only
# 3292  0.0    1.0         right_only
# 3293  1.0    0.0         right_only
# 3294  1.0    1.0         right_only
# 3295  1.0    1.0         right_only
# 3296  1.0    1.0         right_only
# 3297  1.0    2.0         right_only
# 3298  1.0    1.0         right_only
# 3299  1.0    1.0         right_only
# 3300  1.0    1.0         right_only
# 3301  0.0    2.0         right_only
# 3302  1.0    1.0         right_only
# 3303  1.0    1.0         right_only
# 3304  0.0    1.0         right_only
# 3305  1.0    1.0         right_only
# 3306  0.0    1.0         right_only
# 3307  1.0    1.0         right_only
# 3308  0.0    2.0         right_only
# 3309  1.0    2.0         right_only
# 3310  1.0    1.0         right_only
# 3311  0.0    1.0         right_only
# 3312  1.0    1.0         right_only
# 3313  0.0    1.0         right_only
# 3314  1.0    1.0         right_only
# 3315  1.0    1.0         right_only
# 3316  1.0    1.0         right_only
# 3317  1.0    1.0         right_only
# 3318  1.0    1.0         right_only
# 3319  0.0    1.0         right_only
# 3320  1.0    1.0         right_only
# 3321  0.0    1.0         right_only
# 3322  0.0    1.0         right_only
# 3323  0.0    1.0         right_only
# 3324  1.0    1.0         right_only
# 3325  1.0    1.0         right_only
# 3326  1.0    1.0         right_only
# 3327  1.0    1.0         right_only
# 3328  0.0    1.0         right_only
# 3329  0.0    1.0         right_only
# 3330  1.0    1.0         right_only
# 3331  0.0    1.0         right_only
# 3332  0.0    1.0         right_only
# 3333  1.0    1.0         right_only
# 3334  1.0    1.0         right_only
# 3335  0.0    1.0         right_only
# 3336  1.0    2.0         right_only
# 3337  1.0    1.0         right_only
# 3338  0.0    0.0         right_only
# 3339  1.0    1.0         right_only
# 3340  1.0    1.0         right_only
# 3341  1.0    2.0         right_only
# 3342  1.0    1.0         right_only
# 3343  1.0    1.0         right_only
# 3344  1.0    1.0         right_only
# 3345  1.0    1.0         right_only
# 3346  1.0    1.0         right_only
# 3347  1.0    1.0         right_only
# 3348  1.0    1.0         right_only
# 3349  1.0    2.0         right_only
# 3350  0.0    1.0         right_only
# 3351  1.0    1.0         right_only
# 3352  1.0    1.0         right_only
# 3353  1.0    1.0         right_only
# 3354  1.0    2.0         right_only
# 3355  0.0    2.0         right_only
# 3356  1.0    1.0         right_only
# 3357  0.0    1.0         right_only
# 3358  1.0    1.0         right_only
# 3359  1.0    2.0         right_only
# 3360  1.0    2.0         right_only
# 3361  1.0    1.0         right_only
# 3362  0.0    1.0         right_only
# 3363  1.0    1.0         right_only
# 3364  1.0    1.0         right_only
# 3365  0.0    1.0         right_only
# 3366  1.0    1.0         right_only
# 3367  1.0    1.0         right_only
# 3368  1.0    1.0         right_only
# 3369  1.0    1.0         right_only
# 3370  1.0    1.0         right_only
# 3371  1.0    0.0         right_only
# 3372  1.0    1.0         right_only
# 3373  1.0    1.0         right_only
# 3374  1.0    2.0         right_only
# 3375  1.0    1.0         right_only
# 3376  1.0    1.0         right_only
# 3377  1.0    2.0         right_only
# 3378  0.0    1.0         right_only
# 3379  1.0    1.0         right_only
# 3380  1.0    1.0         right_only
# 3381  1.0    1.0         right_only
# 3382  1.0    1.0         right_only
# 3383  1.0    1.0         right_only
# 3384  0.0    1.0         right_only
# 3385  1.0    1.0         right_only
# 3386  1.0    1.0         right_only
# 3387  0.0    2.0         right_only
# 3388  1.0    1.0         right_only
# 3389  1.0    2.0         right_only
# 3390  1.0    1.0         right_only
# 3391  1.0    2.0         right_only
# 3392  1.0    1.0         right_only
# 3393  0.0    1.0         right_only
# 3394  0.0    1.0         right_only
# 3395  1.0    2.0         right_only
# 3396  1.0    1.0         right_only
# 3397  1.0    1.0         right_only
# 3398  1.0    1.0         right_only
# 3399  1.0    1.0         right_only
# 3400  1.0    1.0         right_only
# 3401  1.0    1.0         right_only
# 3402  1.0    2.0         right_only
# 3403  1.0    1.0         right_only
# 3404  0.0    1.0         right_only
# 3405  1.0    1.0         right_only
# 3406  0.0    1.0         right_only
# 3407  1.0    1.0         right_only
# 3408  1.0    1.0         right_only
# 3409  0.0    1.0         right_only
# 3410  1.0    1.0         right_only
# 3411  0.0    1.0         right_only
# 3412  1.0    1.0         right_only
# 3413  1.0    1.0         right_only
# 3414  1.0    1.0         right_only
# 3415  1.0    1.0         right_only
# 3416  0.0    1.0         right_only
# 3417  1.0    2.0         right_only
# 3418  1.0    1.0         right_only
# 3419  1.0    1.0         right_only
# 3420  0.0    1.0         right_only
# 3421  1.0    1.0         right_only
# 3422  0.0    1.0         right_only
# 3423  1.0    1.0         right_only
# 3424  1.0    1.0         right_only
# 3425  1.0    1.0         right_only
# 3426  1.0    2.0         right_only
# 3427  1.0    1.0         right_only
# 3428  0.0    1.0         right_only
# 3429  0.0    1.0         right_only
# 3430  1.0    1.0         right_only
# 3431  1.0    1.0         right_only
# 3432  1.0    1.0         right_only
# 3433  1.0    2.0         right_only
# 3434  1.0    1.0         right_only
# 3435  1.0    1.0         right_only
# 3436  0.0    1.0         right_only
# 3437  1.0    1.0         right_only
# 3438  1.0    2.0         right_only
# 3439  1.0    2.0         right_only
# 3440  1.0    1.0         right_only
# 3441  1.0    1.0         right_only
# 3442  1.0    1.0         right_only
# 3443  1.0    1.0         right_only
# 3444  1.0    1.0         right_only
#
# [3445 rows x 4 columns]
